# %% [markdown]
# # Version Notes
#
# Total sort with ordered partitions has been implemented in questions 5.4.1 B and C. Total sort should not be required for parts A and B of 5.4.1.
#
# Total sort with ordered partitions has been implemented in Step 1 of question 5.5 that identifies the 9,000th - 10,000th most common words. This total sort works, but has not been carefully checked for accuracy.
#
# Total sort with ordered partitions has also been implemented in Step 3 of question 5.5 that calculates similarity scores from the stripes built in Step 2. This has been implemented so that the output is sorted and we can easily get the top 1,000 synonyms for evaluation in step 5.6.
#
#
# ## Action Items.
# 1. Figure out how to more dynamically create the partition files based on the distributions of word counts observed in the data.
#     - Search this document for #Action item 1 for places where this needs to be implemented.
# 2. In question 5.5, output of step 1 currently being written to HDFS per Kyle Hamilton's suggestion. Thus, the list of 9,000th - 10,000th most common words must be pulled from HDFS to a local file that can be read in to the map stage of Step 2 of our implementation of question 5.5.
#     - Search this document for #Action item 2 for the place where this needs to be implemented.
# 3. In question 5.5, the output of step 2 that builds stripes will output to HDFS. Need to figure out how to read the stripes from HDFS into step 3 that calculates similarities.
#     - Search this document for Action item 3 for the place where this needs to be implemented.

# %% [markdown]
# # MIDS - w261 Machine Learning At Scale
# __Course Lead:__ Dr James G. Shanahan (__email__ Jimi via  James.Shanahan _AT_ gmail.com)
#
# ## Assignment - HW5
#
#
# ---
# __Name:__  Nicholas Chen
# __Class:__ MIDS w261 (Section Summer 2017, Group 1)
# __Email:__  nwchen24@iSchool.Berkeley.edu
# __Week:__   5
#
# __Due Time:__ 2 Phases.
#
# * __HW5 Phase 1__
# This can be done on a local machine (with a unit test on the cloud such as AltaScale's PaaS or on AWS) and is due Tuesday, Week 6 by 8AM (West coast time). It will primarily focus on building a unit/systems and for pairwise similarity calculations pipeline (for stripe documents)
#
# * __HW5 Phase 2__
# This will require the AltaScale cluster and will be due Tuesday, Week 7 by 8AM (West coast time).
# The focus of  HW5 Phase 2  will be to scale up the unit/systems tests to the Google 5 gram corpus. This will be a group exercise

# %% [markdown]
# # Table of Contents <a name="TOC"></a>
#
# 1.  [HW Instructions](#1)
# 2.  [HW References](#2)
# 3.  [HW Problems](#3)
#
#     5.4.  [HW5.4](#5.4)
#     5.5.  [HW5.5](#5.5)
#     5.6.  [HW5.6](#5.6)
#     5.7.  [HW5.7](#5.7)
#     5.8.  [HW5.8](#5.8)
#     5.9.  [HW5.9](#5.9)

# %% [markdown]
# <a name="1"></a>
# # 1 Instructions
# [Back to Table of Contents](#TOC)
#
# MIDS UC Berkeley, Machine Learning at Scale
# DATSCIW261 ASSIGNMENT #5
#
# Version 2017-9-2
#
#
# ### IMPORTANT
#
# This homework must be completed in the cloud
#
# ### === INSTRUCTIONS for SUBMISSIONS ===
# Follow the instructions for submissions carefully.
#
# Each student has a `HW-<user>` repository for all assignments.
#
# Click this link to enable you to create a github repo within the MIDS261 Classroom:
# https://classroom.github.com/assignment-invitations/3b1d6c8e58351209f9dd865537111ff8
# and follow the instructions to create a HW repo.
#
# Push the following to your HW github repo into the master branch:
# * Your local HW5 directory. Your repo file structure should look like this:
#
# ```
# HW-<user>
#     --HW3
#        |__MIDS-W261-HW-03-<Student_id>.ipynb
#        |__MIDS-W261-HW-03-<Student_id>.pdf
#        |__some other hw3 file
#     --HW4
#        |__MIDS-W261-HW-04-<Student_id>.ipynb
#        |__MIDS-W261-HW-04-<Student_id>.pdf
#        |__some other hw4 file
#     etc..
# ```

# %% [markdown]
# <a name="2">
# # 2 Useful References
# [Back to Table of Contents](#TOC)
#
# * See async and live lectures for this week

# %% [markdown]
# <a name="3">
# # 3 HW Problems
# [Back to Table of Contents](#TOC)

# %% [markdown]
# <a name="5.4"></a>
# # PHASE 2
# ----------
#
# # HW 5.4
# ## Full-scale experiment on Google N-gram data on the CLOUD
# __ Once you are happy with your test results __ proceed to generating  your results on the Google n-grams dataset.

# %% [markdown]
# ## 3.  HW5.4.0  <a name="5.4.0"></a> Run systems tests on the CLOUD  (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Repeat HW5.3.0 (using the same small data sources that were used in HW5.3.0) on ** the cloud** (e.g., AltaScale / AWS/ SoftLayer/ Azure). Make sure all tests give correct results! Good luck out there!

# %% [markdown]
# ### Job Configs  - Remove this Job Config File when Running on Altiscale
#
# Save this job configs file to tell hadoop which python to use to execute mrjobs. See documentation here:
# http://mrjob.readthedocs.io/en/latest/guides/configs-basics.html#data-type-command
#
# Tried
# /opt/anaconda2/envs/py27/bin/python
# /mnt/ephemeral1/jupyter/anaconda2/envs/py27/bin/python

# %%
# !rm ~/.mrjob.conf
# Out:
# rm: cannot remove `/root/.mrjob.conf': No such file or directory

# %%
# %%writefile /etc/mrjob.conf
#
# runners:
#     hadoop:
#         python_bin: /opt/anaconda/bin/python
# Out:
# Writing /etc/mrjob.conf

# %% [markdown]
# ### Download a single sample of the google n-grams
#
# This sample is for testing on local docker container where

# %%
# !wget -O googlebooks-eng-all-5gram-20090715-0-filtered.txt https://www.dropbox.com/sh/tmqpc4o0xswhkvz/AACr50woxiBWoaiiLmnwduX8a/googlebooks-eng-all-5gram-20090715-0-filtered.txt?dl=0
# Out:
# --2017-06-18 21:37:36--  https://www.dropbox.com/sh/tmqpc4o0xswhkvz/AACr50woxiBWoaiiLmnwduX8a/googlebooks-eng-all-5gram-20090715-0-filtered.txt?dl=0
# Resolving www.dropbox.com... 162.125.8.1
# Connecting to www.dropbox.com|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/iRMfUS8HN4pFfHHaGfaUPf6hmltFwK41cgBzlRJayBfPwAox1rhUMVfpkG92zAi7/file [following]
# --2017-06-18 21:37:37--  https://dl.dropboxusercontent.com/content_link/iRMfUS8HN4pFfHHaGfaUPf6hmltFwK41cgBzlRJayBfPwAox1rhUMVfpkG92zAi7/file
# Resolving dl.dropboxusercontent.com... 162.125.8.6
# Connecting to dl.dropboxusercontent.com|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11444614 (11M) [text/plain]
# Saving to: `googlebooks-eng-all-5gram-20090715-0-filtered.txt'
#
# 100%[======================================>] 11,444,614  2.22M/s   in 6.2s
#
# 2017-06-18 21:37:44 (1.76 MB/s) - `googlebooks-eng-all-5gram-20090715-0-filtered.txt' saved [11444614/11444614]

# %% [markdown]
# ### Write test datasets

# %%
import sys
sys.executable
# Out:
# '/opt/anaconda/bin/python'

# %%
# %%writefile googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt
# A BILL FOR ESTABLISHING RELIGIOUS	59	59	54
# A Biography of General George	92	90	74
# A Case Study in Government	102	102	78
# A Case Study of Female	447	447	327
# A Case Study of Limited	55	55	43
# A Child's Christmas in Wales	1099	1061	866
# A Circumstantial Narrative of the	62	62	50
# A City by the Sea	62	60	49
# A Collection of Fairy Tales	123	117	80
# A Collection of Forms of	116	103	82
# Out:
# Overwriting googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt

# %%
# %%writefile atlas-boon-systems-test.txt
# atlas boon	50	50	50
# boon cava dipped	10	10	10
# atlas dipped	15	15	15
# Out:
# Writing atlas-boon-systems-test.txt

# %%
########################################################################
# Stripes for systems test 3 (given, no need to build stripes)
########################################################################

with open("systems_test_stripes_3", "w") as f:
    f.writelines([
        '"DocA"\t{"X":20, "Y":30, "Z":5}\n',
        '"DocB"\t{"X":100, "Y":20}\n',  
        '"DocC"\t{"M":5, "N":20, "Z":5, "Y":1}\n'
    ])
# !cat systems_test_stripes_3
# Out:
# "DocA"	{"X":20, "Y":30, "Z":5}
# "DocB"	{"X":100, "Y":20}
# "DocC"	{"M":5, "N":20, "Z":5, "Y":1}

# %% [markdown]
# ### Stripes Systems Test

# %%
import collections as cl

test = cl.Counter()

# %%
# %%writefile buildStripes.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import re
import mrjob
import json
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import itertools
import collections as cl
import ast

class MRbuildStripes(MRJob):
  
    #START SUDENT CODE531_STRIPES
    
    #OUTPUT_PROTOCOL = JSONValueProtocol
    
    def steps(self):
        
        JOBCONF_STEP = {
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':'\t',    
            'mapreduce.partition.keycomparator.options': '-k1,1',
            'mapreduce.job.reduces': '1'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP,
                   mapper=self.mapper,
                   reducer_init=self.reducer_init,
                   reducer=self.reducer
                  )
        ]
    
    def mapper(self, _, line):
        
        #instantiate dict to hold stripes
        stripes_dict = {}
        
        #parse the co-occurrence count from the line
        co_occur_count = line.strip().split()[-3]

        #get pairs of words in the 5-gram and create a stripe for each unique word
        #Note the set here ensures that a word that appears more than once in a 5-gram won't be counted as co-occurring with itself
        #Note the permutations here will count both (word1,word2) and (word2,word1)
        for subset in itertools.permutations(sorted(set(line.strip().lower().split()[:-3])), 2):
            if subset[0] not in stripes_dict.keys():
                stripes_dict[subset[0]] = {}
                stripes_dict[subset[0]][subset[1]] = int(co_occur_count)
                
            elif subset[1] not in stripes_dict[subset[0]]:
                stripes_dict[subset[0]][subset[1]] = int(co_occur_count)
                
            else:
                stripes_dict[subset[0]][subset[1]] += int(co_occur_count)
        
        for key in stripes_dict:
            #yield key, json.dumps(stripes_dict[key])
            yield key, json.dumps(stripes_dict[key])

    def reducer_init(self):
        #instantiate placholder current key and counter
        self.placeholder_for_reducer = 0
        
    def reducer(self,key,stripe):
        
        #instantiate counter to hold combined stripes
        cur_counter = cl.Counter()
                
        for stripe_dict in stripe:
            cur_key = key
            
            #load the stripe into a dict
            stripe_dict_to_add = json.loads(stripe_dict)
            
            #update with each stripe
            cur_counter.update(stripe_dict_to_add)

        #output the key and the counter with the sum of all co-occurrences for that key
        yield key, cur_counter
        
        #The placeholder only increments when a new key is encountered
        #reducer seems to get chunks of key value pairs from the mapper with the same key all together
        self.placeholder_for_reducer += 1

    #END SUDENT CODE531_STRIPES

if __name__ == '__main__':
    MRbuildStripes.run()
# Out:
# Overwriting buildStripes.py

# %%
###########################################################################
# Make Stripes from ngrams for systems test 1
###########################################################################

# !hdfs dfs -rm -r systems_test_stripes_1

#Local works
#!python buildStripes.py -r local googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > systems_test_stripes_1   

#Hadoop mode for docker container
# !python buildStripes.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > systems_test_stripes_1   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python buildStripes.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > systems_test_stripes_1 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_stripes_1': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/buildStripes.root.20170618.213929.425598
# Copying local files to hdfs:///user/root/tmp/mrjob/buildStripes.root.20170618.213929.425598/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob561720007080017042.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0003
#   Submitted application application_1497814303217_0003
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0003/
#   Running job: job_1497814303217_0003
#   Job job_1497814303217_0003 running in uber mode : false
#    map 0% reduce 0%
#    map 20% reduce 0%
#    map 39% reduce 0%
#    map 50% reduce 0%
#    map 61% reduce 0%
#    map 80% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 73%
#    map 100% reduce 78%
#    map 100% reduce 84%
#    map 100% reduce 89%
#    map 100% reduce 95%
#    map 100% reduce 100%
#   Job job_1497814303217_0003 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/buildStripes.root.20170618.213929.425598/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=11448710
# 	File Output Format Counters
# 		Bytes Written=19405188
# 	File System Counters
# 		FILE: Number of bytes read=107660872
# 		FILE: Number of bytes written=215677222
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=11449112
# 		HDFS: Number of bytes written=19405188
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=31171584
# 		Total megabyte-seconds taken by all reduce tasks=24404992
# 		Total time spent by all map tasks (ms)=30441
# 		Total time spent by all maps in occupied slots (ms)=30441
# 		Total time spent by all reduce tasks (ms)=23833
# 		Total time spent by all reduces in occupied slots (ms)=23833
# 		Total vcore-seconds taken by all map tasks=30441
# 		Total vcore-seconds taken by all reduce tasks=23833
# 	Map-Reduce Framework
# 		CPU time spent (ms)=48940
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=160
# 		Input split bytes=402
# 		Map input records=311614
# 		Map output bytes=104595452
# 		Map output materialized bytes=107660878
# 		Map output records=1532707
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=1306411008
# 		Reduce input groups=36352
# 		Reduce input records=1532707
# 		Reduce output records=36352
# 		Reduce shuffle bytes=107660878
# 		Shuffled Maps =2
# 		Spilled Records=3065414
# 		Total committed heap usage (bytes)=1131413504
# 		Virtual memory (bytes) snapshot=4119457792
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/buildStripes.root.20170618.213929.425598/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/buildStripes.root.20170618.213929.425598...
# Removing temp directory /tmp/buildStripes.root.20170618.213929.425598...

# %%
# !head -5 systems_test_stripes_1
# Out:
# "a"	{"writings":43,"nunnery":96,"foul":603,"narcotic":123,"four":6411,"gag":88,"prefix":123,"woods":44,"friend's":91,"hanging":197,"localized":134,"conjure":100,"looking":1803,"granting":259,"electricity":489,"clot":158,"johnson's":156,"lore":55,"lord":1506,"shaving":111,"sinking":398,"regional":1190,"grenadiers":41,"stipulate":57,"lotte":43,"leisurely":187,"fur":104,"bringing":3190,"wooded":40,"uttering":221,"prize":1810,"wooden":1543,"broiled":54,"physician's":87,"persisted":85,"succession":1721,"magnocellular":43,"straight":2337,"asian":88,"charter":765,"specially":116,"tired":281,"preface":431,"pulse":139,"elections":255,"feasibility":166,"rampart":43,"second":8097,"sooth":67,"valiant":201,"sailed":42,"horseshoe":77,"prosody":49,"blouse":71,"errors":178,"relieving":239,"spitefulness":44,"thunder":288,"contributed":2389,"fingers":210,"hull":48,"increasing":511,"inducement":88,"pioneering":68,"specialist":114,"hero":544,"reporter":219,"sunbeams":90,"error":1305,"here":8050,"herd":332,"reported":648,"china":1034,"cult":108,"shriek":99,"substance":2284,"coarctation":41,"ass's":42,"k":282,"climbed":280,"reports":671,"controversy":711,"etiology":197,"military":3251,"curable":129,"criticism":884,"golden":1193,"projection":108,"classification":407,"secluded":75,"argo":48,"replace":95,"psychological":942,"remnant":101,"sizeable":61,"stern":592,"involvement":231,"blacking":98,"unit":4661,"derivatives":62,"dna":179,"spoke":1230,"insecurity":179,"glimmering":80,"inevitable":129,"occupying":96,"embarks":99,"panoply":40,"symphony":133,"music":861,"telegraph":64,"mystic":367,"strike":1151,"sermons":94,"until":4441,"females":101,"standardized":400,"holy":2052,"populations":89,"successful":2477,"brings":498,"hereby":66,"sortie":43,"hurt":469,"glass":4910,"reversible":63,"tying":59,"hole":3114,"hold":8992,"unpack":197,"circumstances":370,"intake":87,"editorship":106,"locked":742,"pursue":175,"blade":89,"temperatures":156,"concepts":93,"revenues":468,"example":7190,"triple":403,"wand":513,"unjust":107,"household":209,"organized":1087,"currency":397,"promulgated":294,"caution":173,"want":14257,"counseling":115,"dyke":72,"absolute":352,"hog":292,"downstream":54,"knows":367,"complaining":53,"travel":787,"feature":3378,"machine":2073,"how":13121,"hot":1802,"significance":717,"preferable":83,"activation":72,"dignified":120,"hoy":76,"gaming":90,"abstraction":46,"supplied":133,"beauty":721,"mediating":146,"modulation":62,"typed":46,"nephrotic":203,"conductivity":57,"grading":58,"diagram":805,"wrong":1560,"destined":260,"constants":43,"compartment":47,"entrusted":499,"effective":1127,"green's":89,"recombination":42,"seduce":157,"revolt":145,"headquarters":106,"cigarettes":65,"orally":1883,"ho":132,"keeps":54,"democratic":2934,"wing":213,"wind":2099,"wine":861,"restriction":252,"feedback":442,"oppressors":70,"dreamed":57,"concurrence":475,"misdemeanor":959,"vary":4784,"whizzing":45,"sunshine":126,"rewarded":291,"wrought":103,"fir":178,"fit":3316,"auditory":145,"lifeline":41,"gridiron":105,"occupations":148,"folate":75,"rescued":60,"distinguishing":298,"fig":41,"nobler":245,"nobles":89,"hidden":304,"fin":112,"easier":475,"grievous":117,"accruing":87,"differentiated":56,"elementary":619,"feconde":46,"renunciation":250,"detachment":991,"effects":3540,"premonition":50,"schools":236,"township":58,"comprised":130,"lenient":79,"bricks":74,"structural":1521,"represents":1442,"gallop":136,"blazer":64,"phenotype":101,"seamstress":133,"holiness":149,"tuberculin":132,"crops":183,"arrow":40,"comely":294,"retainers":108,"interfering":48,"burial":54,"preceded":149,"whim":153,"financial":2300,"snakes":53,"concord":134,"knockout":43,"series":35826,"allah":75,"spider":228,"commons":1935,"contracting":296,"depositing":295,"fortnight":713,"substantially":205,"laboratory":209,"whit":81,"whir":48,"ring":2024,"whip":273,"borne":306,"toleration":143,"misfortune":158,"drove":114,"rs":823,"freeze":55,"semiconductor":91,"re":1143,"encourage":157,"dsm":54,"adapt":91,"engineer": ...
# "aa"	{"and":180,"patterned":77,"long":45,"jackson":43,"bb":70,"edited":45,"tate":43,"after":77,"but":77,"stonewall":43,"gc":110,"are":147,"berle":110,"allen":43,"the":70,"by":155,"feminism":45}
# "aahperd"	{"american":44,"alliance":44,"health":44,"for":44}
# "aalborg"	{"city":48,"the":48,"of":48,"in":48}
# "ab"	{"and":163,"a":168,"hollingshead":53,"chord":53,"from":161,"university":161,"that":43,"of":206,"is":168,"lines":57,"equal":80,"cd":57,"to":80,"fc":53,"cannot":57,"the":214,"piece":45,"by":53,"bisects":53,"quantity":43}

# %%
###########################################################################
# Make Stripes from ngrams for systems test 2
###########################################################################

# !hdfs dfs -rm -r systems_test_stripes_2

#Local works
#!python buildStripes.py -r local googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > systems_test_stripes_1   

#Hadoop mode for docker container
# !python buildStripes.py -r hadoop atlas-boon-systems-test.txt > systems_test_stripes_2   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python buildStripes.py -r hadoop atlas-boon-systems-test.txt > systems_test_stripes_2 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_stripes_2': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/buildStripes.root.20170616.204631.939732
# Copying local files to hdfs:///user/root/tmp/mrjob/buildStripes.root.20170616.204631.939732/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob5304532271652937719.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0032
#   Submitted application application_1497107873528_0032
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0032/
#   Running job: job_1497107873528_0032
#   Job job_1497107873528_0032 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0032 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/buildStripes.root.20170616.204631.939732/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=101
# 	File Output Format Counters
# 		Bytes Written=147
# 	File System Counters
# 		FILE: Number of bytes read=244
# 		FILE: Number of bytes written=355903
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=457
# 		HDFS: Number of bytes written=147
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=6816768
# 		Total megabyte-seconds taken by all reduce tasks=3078144
# 		Total time spent by all map tasks (ms)=6657
# 		Total time spent by all maps in occupied slots (ms)=6657
# 		Total time spent by all reduce tasks (ms)=3006
# 		Total time spent by all reduces in occupied slots (ms)=3006
# 		Total vcore-seconds taken by all map tasks=6657
# 		Total vcore-seconds taken by all reduce tasks=3006
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1650
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=49
# 		Input split bytes=356
# 		Map input records=3
# 		Map output bytes=224
# 		Map output materialized bytes=250
# 		Map output records=7
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=738934784
# 		Reduce input groups=4
# 		Reduce input records=7
# 		Reduce output records=4
# 		Reduce shuffle bytes=250
# 		Shuffled Maps =2
# 		Spilled Records=14
# 		Total committed heap usage (bytes)=638058496
# 		Virtual memory (bytes) snapshot=4103888896
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/buildStripes.root.20170616.204631.939732/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/buildStripes.root.20170616.204631.939732...
# Removing temp directory /tmp/buildStripes.root.20170616.204631.939732...

# %%
# !cat systems_test_stripes_2
# Out:
# "atlas"	{"dipped":15,"boon":50}
# "boon"	{"atlas":50,"dipped":10,"cava":10}
# "cava"	{"dipped":10,"boon":10}
# "dipped"	{"atlas":15,"boon":10,"cava":10}

# %% [markdown]
# ### Inverted Index Systems Test

# %%
# %%writefile invertedIndex.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import collections as cl
import re
import json
import math
import numpy as np
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import sys

class MRinvertedIndex(MRJob):
    #START SUDENT CODE531_INV_INDEX
    
    #OUTPUT_PROTOCOL = JSONValueProtocol

    
    def steps(self):
        
        JOBCONF_STEP = {
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':'\t',    
            'mapreduce.partition.keycomparator.options': '-k1,1',
            'mapreduce.job.reduces': '1'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP,
                   mapper=self.mapper,
                   reducer=self.reducer
                  )
        ]
    
    def mapper(self, _, line):
        
        #Read the key and the stripe from the input
        key_stripe_list = line.translate(None,"\n").split("\t")
        
        key = json.loads(key_stripe_list[0])
        stripe = json.loads(key_stripe_list[1])
        
        #get length of the stripe
        stripe_len = len(stripe)
        
        #create dict that will hold doc title and the stripe length
        stripe_len_dict = {key:stripe_len}
        
        for term in stripe:
            yield term, stripe_len_dict
  
    def reducer(self, key, stripe):

        #instantiate a dict where we will combine stripe_len_dicts emitted from mapper
        stripe_len_dict_combined = {}
        
        #Read the incremental stripe length dit from the mapper output
        for stripe_len_dict in stripe:
            
            #update the dict above with each incremental stripe length dict
            stripe_len_dict_combined.update(stripe_len_dict)
                    
        yield key, stripe_len_dict_combined        
        
        #END SUDENT CODE531_INV_INDEX
        
if __name__ == '__main__':
    MRinvertedIndex.run()
# Out:
# Writing invertedIndex.py

# %%
###########################################################################
# Make Inverted Index from stripes in systems test 1
###########################################################################

# !hdfs dfs -rm -r systems_test_inv_index_1

#Local works
#!python invertedIndex.py -r local systems_test_stripes_1 > systems_test_inv_index_1   

#Hadoop mode for docker container
# !python invertedIndex.py -r hadoop systems_test_stripes_1 > systems_test_inv_index_1   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python invertedIndex.py -r hadoop systems_test_stripes_1 > systems_test_inv_index_1 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_inv_index_1': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/invertedIndex.root.20170616.212505.345512
# Copying local files to hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212505.345512/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob1471530380974738148.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0034
#   Submitted application application_1497107873528_0034
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0034/
#   Running job: job_1497107873528_0034
#   Job job_1497107873528_0034 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0034 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212505.345512/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=3177
# 	File Output Format Counters
# 		Bytes Written=1904
# 	File System Counters
# 		FILE: Number of bytes read=3472
# 		FILE: Number of bytes written=362389
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3525
# 		HDFS: Number of bytes written=1904
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=6461440
# 		Total megabyte-seconds taken by all reduce tasks=3236864
# 		Total time spent by all map tasks (ms)=6310
# 		Total time spent by all maps in occupied slots (ms)=6310
# 		Total time spent by all reduce tasks (ms)=3161
# 		Total time spent by all reduces in occupied slots (ms)=3161
# 		Total vcore-seconds taken by all map tasks=6310
# 		Total vcore-seconds taken by all reduce tasks=3161
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1790
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=69
# 		Input split bytes=348
# 		Map input records=28
# 		Map output bytes=3150
# 		Map output materialized bytes=3478
# 		Map output records=158
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=794054656
# 		Reduce input groups=28
# 		Reduce input records=158
# 		Reduce output records=28
# 		Reduce shuffle bytes=3478
# 		Shuffled Maps =2
# 		Spilled Records=316
# 		Total committed heap usage (bytes)=633864192
# 		Virtual memory (bytes) snapshot=4115017728
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212505.345512/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212505.345512...
# Removing temp directory /tmp/invertedIndex.root.20170616.212505.345512...

# %%
# !cat systems_test_inv_index_1
# Out:
# "a"	{"limited":4,"bill":4,"sea":4,"government":4,"collection":5,"general":4,"female":4,"in":7,"establishing":4,"religious":4,"by":4,"biography":4,"christmas":4,"case":7,"city":4,"circumstantial":4,"fairy":4,"for":4,"of":15,"tales":4,"child's":4,"george":4,"forms":3,"narrative":4,"wales":4,"the":7,"study":7}
# "bill"	{"a":27,"religious":4,"for":4,"establishing":4}
# "biography"	{"a":27,"of":15,"george":4,"general":4}
# "by"	{"a":27,"city":4,"the":7,"sea":4}
# "case"	{"a":27,"limited":4,"female":4,"in":7,"of":15,"study":7,"government":4}
# "child's"	{"a":27,"wales":4,"christmas":4,"in":7}
# "christmas"	{"a":27,"wales":4,"child's":4,"in":7}
# "circumstantial"	{"a":27,"of":15,"the":7,"narrative":4}
# "city"	{"a":27,"the":7,"by":4,"sea":4}
# "collection"	{"a":27,"forms":3,"fairy":4,"tales":4,"of":15}
# "establishing"	{"a":27,"bill":4,"religious":4,"for":4}
# "fairy"	{"a":27,"of":15,"tales":4,"collection":5}
# "female"	{"case":7,"of":15,"study":7,"a":27}
# "for"	{"a":27,"bill":4,"religious":4,"establishing":4}
# "forms"	{"a":27,"of":15,"collection":5}
# "general"	{"a":27,"of":15,"george":4,"biography":4}
# "george"	{"a":27,"of":15,"biography":4,"general":4}
# "government"	{"case":7,"a":27,"study":7,"in":7}
# "in"	{"a":27,"case":7,"government":4,"wales":4,"study":7,"child's":4,"christmas":4}
# "limited"	{"case":7,"a":27,"study":7,"of":15}
# "narrative"	{"a":27,"of":15,"the":7,"circumstantial":4}
# "of"	{"case":7,"a":27,"circumstantial":4,"limited":4,"the":7,"study":7,"collection":5,"general":4,"forms":3,"tales":4,"female":4,"narrative":4,"fairy":4,"george":4,"biography":4}
# "religious"	{"a":27,"bill":4,"for":4,"establishing":4}
# "sea"	{"a":27,"city":4,"the":7,"by":4}
# "study"	{"case":7,"limited":4,"a":27,"female":4,"government":4,"of":15,"in":7}
# "tales"	{"a":27,"of":15,"fairy":4,"collection":5}
# "the"	{"a":27,"city":4,"circumstantial":4,"sea":4,"narrative":4,"of":15,"by":4}
# "wales"	{"a":27,"in":7,"christmas":4,"child's":4}

# %%
###########################################################################
# Make Inverted Index from stripes in systems test 2
###########################################################################

# !hdfs dfs -rm -r systems_test_inv_index_2

#Local works
#!python invertedIndex.py -r local systems_test_stripes_2 > systems_test_inv_index_2   

#Hadoop mode for docker container
# !python invertedIndex.py -r hadoop systems_test_stripes_2 > systems_test_inv_index_2   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python invertedIndex.py -r hadoop systems_test_stripes_2 > systems_test_inv_index_2 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_inv_index_2': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/invertedIndex.root.20170616.212609.534296
# Copying local files to hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212609.534296/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob4350210489214509464.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0035
#   Submitted application application_1497107873528_0035
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0035/
#   Running job: job_1497107873528_0035
#   Job job_1497107873528_0035 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0035 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212609.534296/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=221
# 	File Output Format Counters
# 		Bytes Written=137
# 	File System Counters
# 		FILE: Number of bytes read=222
# 		FILE: Number of bytes written=355889
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=569
# 		HDFS: Number of bytes written=137
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=7558144
# 		Total megabyte-seconds taken by all reduce tasks=3257344
# 		Total time spent by all map tasks (ms)=7381
# 		Total time spent by all maps in occupied slots (ms)=7381
# 		Total time spent by all reduce tasks (ms)=3181
# 		Total time spent by all reduces in occupied slots (ms)=3181
# 		Total vcore-seconds taken by all map tasks=7381
# 		Total vcore-seconds taken by all reduce tasks=3181
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1940
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=58
# 		Input split bytes=348
# 		Map input records=4
# 		Map output bytes=196
# 		Map output materialized bytes=228
# 		Map output records=10
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=732114944
# 		Reduce input groups=4
# 		Reduce input records=10
# 		Reduce output records=4
# 		Reduce shuffle bytes=228
# 		Shuffled Maps =2
# 		Spilled Records=20
# 		Total committed heap usage (bytes)=638058496
# 		Virtual memory (bytes) snapshot=4106346496
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212609.534296/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212609.534296...
# Removing temp directory /tmp/invertedIndex.root.20170616.212609.534296...

# %%
# !cat systems_test_inv_index_2
# Out:
# "atlas"	{"dipped":3,"boon":3}
# "boon"	{"atlas":2,"dipped":3,"cava":2}
# "cava"	{"dipped":3,"boon":3}
# "dipped"	{"atlas":2,"boon":3,"cava":2}

# %%
###########################################################################
# Make Inverted Index from stripes in systems test 3
###########################################################################

# !hdfs dfs -rm -r systems_test_inv_index_3

#Local works
#!python invertedIndex.py -r local systems_test_stripes_3 > systems_test_inv_index_3   

#Hadoop mode for docker container
# !python invertedIndex.py -r hadoop systems_test_stripes_3 > systems_test_inv_index_3   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python invertedIndex.py -r hadoop systems_test_stripes_3 > systems_test_inv_index_3 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_inv_index_3': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/invertedIndex.root.20170616.212854.887278
# Copying local files to hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212854.887278/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob7061201187121360152.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0036
#   Submitted application application_1497107873528_0036
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0036/
#   Running job: job_1497107873528_0036
#   Job job_1497107873528_0036 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0036 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212854.887278/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=140
# 	File Output Format Counters
# 		Bytes Written=111
# 	File System Counters
# 		FILE: Number of bytes read=159
# 		FILE: Number of bytes written=355763
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=488
# 		HDFS: Number of bytes written=111
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=6405120
# 		Total megabyte-seconds taken by all reduce tasks=3416064
# 		Total time spent by all map tasks (ms)=6255
# 		Total time spent by all maps in occupied slots (ms)=6255
# 		Total time spent by all reduce tasks (ms)=3336
# 		Total time spent by all reduces in occupied slots (ms)=3336
# 		Total vcore-seconds taken by all map tasks=6255
# 		Total vcore-seconds taken by all reduce tasks=3336
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1720
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=56
# 		Input split bytes=348
# 		Map input records=3
# 		Map output bytes=135
# 		Map output materialized bytes=165
# 		Map output records=9
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=727425024
# 		Reduce input groups=5
# 		Reduce input records=9
# 		Reduce output records=5
# 		Reduce shuffle bytes=165
# 		Shuffled Maps =2
# 		Spilled Records=18
# 		Total committed heap usage (bytes)=640155648
# 		Virtual memory (bytes) snapshot=4104859648
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212854.887278/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/invertedIndex.root.20170616.212854.887278...
# Removing temp directory /tmp/invertedIndex.root.20170616.212854.887278...

# %%
# !cat systems_test_inv_index_3
# Out:
# "M"	{"DocC":4}
# "N"	{"DocC":4}
# "X"	{"DocB":2,"DocA":3}
# "Y"	{"DocB":2,"DocC":4,"DocA":3}
# "Z"	{"DocC":4,"DocA":3}

# %% [markdown]
# ### Similarity Systems Test

# %%
# %%writefile similarity.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import collections
import re
import json
import math
import numpy as np
import itertools
import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep

class MRsimilarity(MRJob):
  
    #START SUDENT CODE531_SIMILARITY
    #OUTPUT_PROTOCOL = JSONValueProtocol
    
    def steps(self):
        
        JOBCONF_STEP = {
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':'\t',    
            'stream.num.map.output.key.fields': '2',
            'mapreduce.partition.keycomparator.options': '-k1,1',
            'mapreduce.job.reduces': '1'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP,
                   mapper=self.mapper,
                   reducer=self.reducer
                  )
        ]
    
    def mapper(self, _, line):
        
        #Read the key and the stripe from the input
        key_index_list = line.translate(None,"\n").split("\t")
        
        key = json.loads(key_index_list[0])
        inv_index = json.loads(key_index_list[1])
        
        for subset in itertools.permutations(sorted(set(inv_index.keys())), 2):
            
            #get the lengths of each item that we want to output
            item_1_len = inv_index[subset[0]]
            item_2_len = inv_index[subset[1]]
            
            #create a two item dict to hold the item names and their lengths
            item_len_dict = {}
            item_len_dict[subset[0]] = item_1_len
            item_len_dict[subset[1]] = item_2_len
            
            #when output like this, can index with key[0] to get subset[0] in the reducer
            yield (subset[0], subset[1]), (1,item_len_dict)
  
    def reducer(self, key, stripe):

        #instantiate object to hold the number of times the terms / documents intersect
        items_intersect = 0
        cosine_sim_product = 0
        
        #the reducer gets output from the mapper in chunks grouped by key
        for n,item_len_dict in stripe:
            
            #get the length of item 1 and item 2
            item_1_len = item_len_dict[key[0]]
            item_2_len = item_len_dict[key[1]]
            
            #increment the intersect count
            items_intersect = items_intersect + n
            
            cosine_sim_product = cosine_sim_product + (1/np.sqrt(item_1_len)) * (1/np.sqrt(item_2_len))
            
        #calculate jacard similarity score
        jacard_sim_score = float(items_intersect)/ float(item_1_len + item_2_len - items_intersect)
        
        #Record cosine similarity score before moving on to the next chunk
        cosine_sim_score = cosine_sim_product
        
        yield key, (jacard_sim_score, cosine_sim_score)   
    
    #END SUDENT CODE531_SIMILARITY

if __name__ == '__main__':
    MRsimilarity.run()
# Out:
# Writing similarity.py

# %%
###########################################################################
# Document similarity from inverted index
###########################################################################

# !hdfs dfs -rm -r systems_test_doc_similarity_1

#Local works
#!python similarity.py -r local systems_test_inv_index_1 > systems_test_doc_similarity_1   

#Hadoop mode for docker container
# !python similarity.py -r hadoop systems_test_inv_index_1 > systems_test_doc_similarity_1   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python similarity.py -r hadoop systems_test_inv_index_1 > systems_test_inv_index_1 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_doc_similarity_1': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/similarity.root.20170616.213334.840861
# Copying local files to hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213334.840861/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob7089235033877818556.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0037
#   Submitted application application_1497107873528_0037
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0037/
#   Running job: job_1497107873528_0037
#   Job job_1497107873528_0037 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0037 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213334.840861/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=2856
# 	File Output Format Counters
# 		Bytes Written=31230
# 	File System Counters
# 		FILE: Number of bytes read=67178
# 		FILE: Number of bytes written=490095
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=3202
# 		HDFS: Number of bytes written=31230
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=7317504
# 		Total megabyte-seconds taken by all reduce tasks=3115008
# 		Total time spent by all map tasks (ms)=7146
# 		Total time spent by all maps in occupied slots (ms)=7146
# 		Total time spent by all reduce tasks (ms)=3042
# 		Total time spent by all reduces in occupied slots (ms)=3042
# 		Total vcore-seconds taken by all map tasks=7146
# 		Total vcore-seconds taken by all reduce tasks=3042
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1960
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=64
# 		Input split bytes=346
# 		Map input records=28
# 		Map output bytes=64480
# 		Map output materialized bytes=67184
# 		Map output records=1346
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=758325248
# 		Reduce input groups=756
# 		Reduce input records=1346
# 		Reduce output records=756
# 		Reduce shuffle bytes=67184
# 		Shuffled Maps =2
# 		Spilled Records=2692
# 		Total committed heap usage (bytes)=635961344
# 		Virtual memory (bytes) snapshot=4089794560
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213334.840861/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213334.840861...
# Removing temp directory /tmp/similarity.root.20170616.213334.840861...

# %%
# !cat systems_test_doc_similarity_1
# Out:
# ["a","bill"]	[0.1071428571,0.2886751346]
# ["a","biography"]	[0.1071428571,0.2886751346]
# ["a","by"]	[0.1071428571,0.2886751346]
# ["a","case"]	[0.2142857143,0.4364357805]
# ["a","child's"]	[0.1071428571,0.2886751346]
# ["a","christmas"]	[0.1071428571,0.2886751346]
# ["a","circumstantial"]	[0.1071428571,0.2886751346]
# ["a","city"]	[0.1071428571,0.2886751346]
# ["a","collection"]	[0.1428571429,0.3442651863]
# ["a","establishing"]	[0.1071428571,0.2886751346]
# ["a","fairy"]	[0.1071428571,0.2886751346]
# ["a","female"]	[0.1071428571,0.2886751346]
# ["a","for"]	[0.1071428571,0.2886751346]
# ["a","forms"]	[0.0714285714,0.2222222222]
# ["a","general"]	[0.1071428571,0.2886751346]
# ["a","george"]	[0.1071428571,0.2886751346]
# ["a","government"]	[0.1071428571,0.2886751346]
# ["a","in"]	[0.2142857143,0.4364357805]
# ["a","limited"]	[0.1071428571,0.2886751346]
# ["a","narrative"]	[0.1071428571,0.2886751346]
# ["a","of"]	[0.5,0.695665593]
# ["a","religious"]	[0.1071428571,0.2886751346]
# ["a","sea"]	[0.1071428571,0.2886751346]
# ["a","study"]	[0.2142857143,0.4364357805]
# ["a","tales"]	[0.1071428571,0.2886751346]
# ["a","the"]	[0.2142857143,0.4364357805]
# ["a","wales"]	[0.1071428571,0.2886751346]
# ["bill","a"]	[0.1071428571,0.2886751346]
# ["bill","biography"]	[0.1428571429,0.25]
# ["bill","by"]	[0.1428571429,0.25]
# ["bill","case"]	[0.1,0.1889822365]
# ["bill","child's"]	[0.1428571429,0.25]
# ["bill","christmas"]	[0.1428571429,0.25]
# ["bill","circumstantial"]	[0.1428571429,0.25]
# ["bill","city"]	[0.1428571429,0.25]
# ["bill","collection"]	[0.125,0.2236067977]
# ["bill","establishing"]	[0.6,0.75]
# ["bill","fairy"]	[0.1428571429,0.25]
# ["bill","female"]	[0.1428571429,0.25]
# ["bill","for"]	[0.6,0.75]
# ["bill","forms"]	[0.1666666667,0.2886751346]
# ["bill","general"]	[0.1428571429,0.25]
# ["bill","george"]	[0.1428571429,0.25]
# ["bill","government"]	[0.1428571429,0.25]
# ["bill","in"]	[0.1,0.1889822365]
# ["bill","limited"]	[0.1428571429,0.25]
# ["bill","narrative"]	[0.1428571429,0.25]
# ["bill","of"]	[0.0555555556,0.1290994449]
# ["bill","religious"]	[0.6,0.75]
# ["bill","sea"]	[0.1428571429,0.25]
# ["bill","study"]	[0.1,0.1889822365]
# ["bill","tales"]	[0.1428571429,0.25]
# ["bill","the"]	[0.1,0.1889822365]
# ["bill","wales"]	[0.1428571429,0.25]
# ["biography","a"]	[0.1071428571,0.2886751346]
# ["biography","bill"]	[0.1428571429,0.25]
# ["biography","by"]	[0.1428571429,0.25]
# ["biography","case"]	[0.2222222222,0.377964473]
# ["biography","child's"]	[0.1428571429,0.25]
# ["biography","christmas"]	[0.1428571429,0.25]
# ["biography","circumstantial"]	[0.3333333333,0.5]
# ["biography","city"]	[0.1428571429,0.25]
# ["biography","collection"]	[0.2857142857,0.4472135955]
# ["biography","establishing"]	[0.1428571429,0.25]
# ["biography","fairy"]	[0.3333333333,0.5]
# ["biography","female"]	[0.3333333333,0.5]
# ["biography","for"]	[0.1428571429,0.25]
# ["biography","forms"]	[0.4,0.5773502692]
# ["biography","general"]	[0.6,0.75]
# ["biography","george"]	[0.6,0.75]
# ["biography","government"]	[0.1428571429,0.25]
# ["biography","in"]	[0.1,0.1889822365]
# ["biography","limited"]	[0.3333333333,0.5]
# ["biography","narrative"]	[0.3333333333,0.5]
# ["biography","of"]	[0.1875,0.3872983346]
# ["biography","religious"]	[0.1428571429,0.25]
# ["biography","sea"]	[0.1428571429,0.25]
# ["biography","study"]	[0.2222222222,0.377964473]
# ["biography","tales"]	[0.3333333333,0.5]
# ["biography","the"]	[0.2222222222,0.377964473]
# ["biography","wales"]	[0.1428571429,0.25]
# ["by","a"]	[0.1071428571,0.2886751346]
# ["by","bill"]	[0.1428571429,0.25]
# ["by","biography"]	[0.1428571429,0.25]
# ["by","case"]	[0.1,0.1889822365]
# ["by","child's"]	[0.1428571429,0.25]
# ["by","christmas"]	[0.1428571429,0.25]
# ["by","circumstantial"]	[0.3333333333,0.5]
# ["by","city"]	[0.6,0.75]
# ["by","collection"]	[0.125,0.2236067977]
# ["by","establishing"]	[0.1428571429,0.25]
# ["by","fairy"]	[0.1428571429,0.25]
# ["by","female"]	[0.1428571429,0.25]
# ["by","for"]	[0.1428571429,0.25]
# ["by","forms"]	[0.1666666667,0.2886751346]
# ["by","general"]	[0.1428571429,0.25]
# ["by","george"]	[0.1428571429,0.25]
# ["by","government"]	[0.1428571429,0.25]
# ["by","in"]	[0.1,0.1889822365]
# ["by","limited"]	[0.1428571429,0.25]
# ["by","narrative"]	[0.3333333333,0.5]
# ["by","of"]	[0.1176470588,0.2581988897]
# ["by","religious"]	[0.1428571429,0.25]
# ["by","sea"]	[0.6,0.75]
# ["by","study"]	[0.1,0.1889822365]
# ["by","tales"]	[0.1428571429,0.25]
# ["by","the"]	[0.375,0.5669467095]
# ["by","wales"]	[0.1428571429,0.25]
# ["case","a"]	[0.2142857143,0.4364357805]
# ["case","bill"]	[0.1,0.1889822365]
# ["case","biography"]	[0.2222222222,0.377964473]
# ["case","by"]	[0.1,0.1889822365]
# ["case","child's"]	[0.2222222222,0.377964473]
# ["case","christmas"]	[0.2222222222,0.377964473]
# ["case","circumstantial"]	[0.2222222222,0.377964473]
# ["case","city"]	[0.1,0.1889822365]
# ["case","collection"]	[0.2,0.3380617019]
# ["case","establishing"]	[0.1,0.1889822365]
# ["case","fairy"]	[0.2222222222,0.377964473]
# ["case","female"]	[0.375,0.5669467095]
# ["case","for"]	[0.1,0.1889822365]
# ["case","forms"]	[0.25,0.4364357805]
# ["case","general"]	[0.2222222222,0.377964473]
# ["case","george"]	[0.2222222222,0.377964473]
# ["case","government"]	[0.375,0.5669467095]
# ["case","in"]	[0.2727272727,0.4285714286]
# ["case","limited"]	[0.375,0.5669467095]
# ["case","narrative"]	[0.2222222222,0.377964473]
# ["case","of"]	[0.2222222222,0.3903600292]
# ["case","religious"]	[0.1,0.1889822365]
# ["case","sea"]	[0.1,0.1889822365]
# ["case","study"]	[0.75,0.8571428571]
# ["case","tales"]	[0.2222222222,0.377964473]
# ["case","the"]	[0.1666666667,0.2857142857]
# ["case","wales"]	[0.2222222222,0.377964473]
# ["child's","a"]	[0.1071428571,0.2886751346]
# ["child's","bill"]	[0.1428571429,0.25]
# ["child's","biography"]	[0.1428571429,0.25]
# ["child's","by"]	[0.1428571429,0.25]
# ["child's","case"]	[0.2222222222,0.377964473]
# ["child's","christmas"]	[0.6,0.75]
# ["child's","circumstantial"]	[0.1428571429,0.25]
# ["child's","city"]	[0.1428571429,0.25]
# ["child's","collection"]	[0.125,0.2236067977]
# ["child's","establishing"]	[0.1428571429,0.25]
# ["child's","fairy"]	[0.1428571429,0.25]
# ["child's","female"]	[0.1428571429,0.25]
# ["child's","for"]	[0.1428571429,0.25]
# ["child's","forms"]	[0.1666666667,0.2886751346]
# ["child's","general"]	[0.1428571429,0.25]
# ["child's","george"]	[0.1428571429,0.25]
# ["child's","government"]	[0.3333333333,0.5]
# ["child's","in"]	[0.375,0.5669467095]
# ["child's","limited"]	[0.1428571429,0.25]
# ["child's","narrative"]	[0.1428571429,0.25]
# ["child's","of"]	[0.0555555556,0.1290994449]
# ["child's","religious"]	[0.1428571429,0.25]
# ["child's","sea"]	[0.1428571429,0.25]
# ["child's","study"]	[0.2222222222,0.377964473]
# ["child's","tales"]	[0.1428571429,0.25]
# ["child's","the"]	[0.1,0.1889822365]
# ["child's","wales"]	[0.6,0.75]
# ["christmas","a"]	[0.1071428571,0.2886751346]
# ["christmas","bill"]	[0.1428571429,0.25]
# ["christmas","biography"]	[0.1428571429,0.25]
# ["christmas","by"]	[0.1428571429,0.25]
# ["christmas","case"]	[0.2222222222,0.377964473]
# ["christmas","child's"]	[0.6,0.75]
# ["christmas","circumstantial"]	[0.1428571429,0.25]
# ["christmas","city"]	[0.1428571429,0.25]
# ["christmas","collection"]	[0.125,0.2236067977]
# ["christmas","establishing"]	[0.1428571429,0.25]
# ["christmas","fairy"]	[0.1428571429,0.25]
# ["christmas","female"]	[0.1428571429,0.25]
# ["christmas","for"]	[0.1428571429,0.25]
# ["christmas","forms"]	[0.1666666667,0.2886751346]
# ["christmas","general"]	[0.1428571429,0.25]
# ["christmas","george"]	[0.1428571429,0.25]
# ["christmas","government"]	[0.3333333333,0.5]
# ["christmas","in"]	[0.375,0.5669467095]
# ["christmas","limited"]	[0.1428571429,0.25]
# ["christmas","narrative"]	[0.1428571429,0.25]
# ["christmas","of"]	[0.0555555556,0.1290994449]
# ["christmas","religious"]	[0.1428571429,0.25]
# ["christmas","sea"]	[0.1428571429,0.25]
# ["christmas","study"]	[0.2222222222,0.377964473]
# ["christmas","tales"]	[0.1428571429,0.25]
# ["christmas","the"]	[0.1,0.1889822365]
# ["christmas","wales"]	[0.6,0.75]
# ["circumstantial","a"]	[0.1071428571,0.2886751346]
# ["circumstantial","bill"]	[0.1428571429,0.25]
# ["circumstantial","biography"]	[0.3333333333,0.5]
# ["circumstantial","by"]	[0.3333333333,0.5]
# ["circumstantial","case"]	[0.2222222222,0.377964473]
# ["circumstantial","child's"]	[0.1428571429,0.25]
# ["circumstantial","christmas"]	[0.1428571429,0.25]
# ["circumstantial","city"]	[0.3333333333,0.5]
# ["circumstantial","collection"]	[0.2857142857,0.4472135955]
# ["circumstantial","establishing"]	[0.1428571429,0.25]
# ["circumstantial","fairy"]	[0.3333333333,0.5]
# ["circumstantial","female"]	[0.3333333333,0.5]
# ["circumstantial","for"]	[0.1428571429,0.25]
# ["circumstantial","forms"]	[0.4,0.5773502692]
# ["circumstantial","general"]	[0.3333333333,0.5]
# ["circumstantial","george"]	[0.3333333333,0.5]
# ["circumstantial","government"]	[0.1428571429,0.25]
# ["circumstantial","in"]	[0.1,0.1889822365]
# ["circumstantial","limited"]	[0.3333333333,0.5]
# ["circumstantial","narrative"]	[0.6,0.75]
# ["circumstantial","of"]	[0.1875,0.3872983346]
# ["circumstantial","religious"]	[0.1428571429,0.25]
# ["circumstantial","sea"]	[0.3333333333,0.5]
# ["circumstantial","study"]	[0.2222222222,0.377964473]
# ["circumstantial","tales"]	[0.3333333333,0.5]
# ["circumstantial","the"]	[0.375,0.5669467095]
# ["circumstantial","wales"]	[0.1428571429,0.25]
# ["city","a"]	[0.1071428571,0.2886751346]
# ["city","bill"]	[0.1428571429,0.25]
# ["city","biography"]	[0.1428571429,0.25]
# ["city","by"]	[0.6,0.75]
# ["city","case"]	[0.1,0.1889822365]
# ["city","child's"]	[0.1428571429,0.25]
# ["city","christmas"]	[0.1428571429,0.25]
# ["city","circumstantial"]	[0.3333333333,0.5]
# ["city","collection"]	[0.125,0.2236067977]
# ["city","establishing"]	[0.1428571429,0.25]
# ["city","fairy"]	[0.1428571429,0.25]
# ["city","female"]	[0.1428571429,0.25]
# ["city","for"]	[0.1428571429,0.25]
# ["city","forms"]	[0.1666666667,0.2886751346]
# ["city","general"]	[0.1428571429,0.25]
# ["city","george"]	[0.1428571429,0.25]
# ["city","government"]	[0.1428571429,0.25]
# ["city","in"]	[0.1,0.1889822365]
# ["city","limited"]	[0.1428571429,0.25]
# ["city","narrative"]	[0.3333333333,0.5]
# ["city","of"]	[0.1176470588,0.2581988897]
# ["city","religious"]	[0.1428571429,0.25]
# ["city","sea"]	[0.6,0.75]
# ["city","study"]	[0.1,0.1889822365]
# ["city","tales"]	[0.1428571429,0.25]
# ["city","the"]	[0.375,0.5669467095]
# ["city","wales"]	[0.1428571429,0.25]
# ["collection","a"]	[0.1428571429,0.3442651863]
# ["collection","bill"]	[0.125,0.2236067977]
# ["collection","biography"]	[0.2857142857,0.4472135955]
# ["collection","by"]	[0.125,0.2236067977]
# ["collection","case"]	[0.2,0.3380617019]
# ["collection","child's"]	[0.125,0.2236067977]
# ["collection","christmas"]	[0.125,0.2236067977]
# ["collection","circumstantial"]	[0.2857142857,0.4472135955]
# ["collection","city"]	[0.125,0.2236067977]
# ["collection","establishing"]	[0.125,0.2236067977]
# ["collection","fairy"]	[0.5,0.6708203932]
# ["collection","female"]	[0.2857142857,0.4472135955]
# ["collection","for"]	[0.125,0.2236067977]
# ["collection","forms"]	[0.3333333333,0.5163977795]
# ["collection","general"]	[0.2857142857,0.4472135955]
# ["collection","george"]	[0.2857142857,0.4472135955]
# ["collection","government"]	[0.125,0.2236067977]
# ["collection","in"]	[0.0909090909,0.1690308509]
# ["collection","limited"]	[0.2857142857,0.4472135955]
# ["collection","narrative"]	[0.2857142857,0.4472135955]
# ["collection","of"]	[0.25,0.4618802154]
# ["collection","religious"]	[0.125,0.2236067977]
# ["collection","sea"]	[0.125,0.2236067977]
# ["collection","study"]	[0.2,0.3380617019]
# ["collection","tales"]	[0.5,0.6708203932]
# ["collection","the"]	[0.2,0.3380617019]
# ["collection","wales"]	[0.125,0.2236067977]
# ["establishing","a"]	[0.1071428571,0.2886751346]
# ["establishing","bill"]	[0.6,0.75]
# ["establishing","biography"]	[0.1428571429,0.25]
# ["establishing","by"]	[0.1428571429,0.25]
# ["establishing","case"]	[0.1,0.1889822365]
# ["establishing","child's"]	[0.1428571429,0.25]
# ["establishing","christmas"]	[0.1428571429,0.25]
# ["establishing","circumstantial"]	[0.1428571429,0.25]
# ["establishing","city"]	[0.1428571429,0.25]
# ["establishing","collection"]	[0.125,0.2236067977]
# ["establishing","fairy"]	[0.1428571429,0.25]
# ["establishing","female"]	[0.1428571429,0.25]
# ["establishing","for"]	[0.6,0.75]
# ["establishing","forms"]	[0.1666666667,0.2886751346]
# ["establishing","general"]	[0.1428571429,0.25]
# ["establishing","george"]	[0.1428571429,0.25]
# ["establishing","government"]	[0.1428571429,0.25]
# ["establishing","in"]	[0.1,0.1889822365]
# ["establishing","limited"]	[0.1428571429,0.25]
# ["establishing","narrative"]	[0.1428571429,0.25]
# ["establishing","of"]	[0.0555555556,0.1290994449]
# ["establishing","religious"]	[0.6,0.75]
# ["establishing","sea"]	[0.1428571429,0.25]
# ["establishing","study"]	[0.1,0.1889822365]
# ["establishing","tales"]	[0.1428571429,0.25]
# ["establishing","the"]	[0.1,0.1889822365]
# ["establishing","wales"]	[0.1428571429,0.25]
# ["fairy","a"]	[0.1071428571,0.2886751346]
# ["fairy","bill"]	[0.1428571429,0.25]
# ["fairy","biography"]	[0.3333333333,0.5]
# ["fairy","by"]	[0.1428571429,0.25]
# ["fairy","case"]	[0.2222222222,0.377964473]
# ["fairy","child's"]	[0.1428571429,0.25]
# ["fairy","christmas"]	[0.1428571429,0.25]
# ["fairy","circumstantial"]	[0.3333333333,0.5]
# ["fairy","city"]	[0.1428571429,0.25]
# ["fairy","collection"]	[0.5,0.6708203932]
# ["fairy","establishing"]	[0.1428571429,0.25]
# ["fairy","female"]	[0.3333333333,0.5]
# ["fairy","for"]	[0.1428571429,0.25]
# ["fairy","forms"]	[0.75,0.8660254038]
# ["fairy","general"]	[0.3333333333,0.5]
# ["fairy","george"]	[0.3333333333,0.5]
# ["fairy","government"]	[0.1428571429,0.25]
# ["fairy","in"]	[0.1,0.1889822365]
# ["fairy","limited"]	[0.3333333333,0.5]
# ["fairy","narrative"]	[0.3333333333,0.5]
# ["fairy","of"]	[0.1875,0.3872983346]
# ["fairy","religious"]	[0.1428571429,0.25]
# ["fairy","sea"]	[0.1428571429,0.25]
# ["fairy","study"]	[0.2222222222,0.377964473]
# ["fairy","tales"]	[0.6,0.75]
# ["fairy","the"]	[0.2222222222,0.377964473]
# ["fairy","wales"]	[0.1428571429,0.25]
# ["female","a"]	[0.1071428571,0.2886751346]
# ["female","bill"]	[0.1428571429,0.25]
# ["female","biography"]	[0.3333333333,0.5]
# ["female","by"]	[0.1428571429,0.25]
# ["female","case"]	[0.375,0.5669467095]
# ["female","child's"]	[0.1428571429,0.25]
# ["female","christmas"]	[0.1428571429,0.25]
# ["female","circumstantial"]	[0.3333333333,0.5]
# ["female","city"]	[0.1428571429,0.25]
# ["female","collection"]	[0.2857142857,0.4472135955]
# ["female","establishing"]	[0.1428571429,0.25]
# ["female","fairy"]	[0.3333333333,0.5]
# ["female","for"]	[0.1428571429,0.25]
# ["female","forms"]	[0.4,0.5773502692]
# ["female","general"]	[0.3333333333,0.5]
# ["female","george"]	[0.3333333333,0.5]
# ["female","government"]	[0.6,0.75]
# ["female","in"]	[0.375,0.5669467095]
# ["female","limited"]	[1.0,1.0]
# ["female","narrative"]	[0.3333333333,0.5]
# ["female","of"]	[0.1875,0.3872983346]
# ["female","religious"]	[0.1428571429,0.25]
# ["female","sea"]	[0.1428571429,0.25]
# ["female","study"]	[0.375,0.5669467095]
# ["female","tales"]	[0.3333333333,0.5]
# ["female","the"]	[0.2222222222,0.377964473]
# ["female","wales"]	[0.1428571429,0.25]
# ["for","a"]	[0.1071428571,0.2886751346]
# ["for","bill"]	[0.6,0.75]
# ["for","biography"]	[0.1428571429,0.25]
# ["for","by"]	[0.1428571429,0.25]
# ["for","case"]	[0.1,0.1889822365]
# ["for","child's"]	[0.1428571429,0.25]
# ["for","christmas"]	[0.1428571429,0.25]
# ["for","circumstantial"]	[0.1428571429,0.25]
# ["for","city"]	[0.1428571429,0.25]
# ["for","collection"]	[0.125,0.2236067977]
# ["for","establishing"]	[0.6,0.75]
# ["for","fairy"]	[0.1428571429,0.25]
# ["for","female"]	[0.1428571429,0.25]
# ["for","forms"]	[0.1666666667,0.2886751346]
# ["for","general"]	[0.1428571429,0.25]
# ["for","george"]	[0.1428571429,0.25]
# ["for","government"]	[0.1428571429,0.25]
# ["for","in"]	[0.1,0.1889822365]
# ["for","limited"]	[0.1428571429,0.25]
# ["for","narrative"]	[0.1428571429,0.25]
# ["for","of"]	[0.0555555556,0.1290994449]
# ["for","religious"]	[0.6,0.75]
# ["for","sea"]	[0.1428571429,0.25]
# ["for","study"]	[0.1,0.1889822365]
# ["for","tales"]	[0.1428571429,0.25]
# ["for","the"]	[0.1,0.1889822365]
# ["for","wales"]	[0.1428571429,0.25]
# ["forms","a"]	[0.0714285714,0.2222222222]
# ["forms","bill"]	[0.1666666667,0.2886751346]
# ["forms","biography"]	[0.4,0.5773502692]
# ["forms","by"]	[0.1666666667,0.2886751346]
# ["forms","case"]	[0.25,0.4364357805]
# ["forms","child's"]	[0.1666666667,0.2886751346]
# ["forms","christmas"]	[0.1666666667,0.2886751346]
# ["forms","circumstantial"]	[0.4,0.5773502692]
# ["forms","city"]	[0.1666666667,0.2886751346]
# ["forms","collection"]	[0.3333333333,0.5163977795]
# ["forms","establishing"]	[0.1666666667,0.2886751346]
# ["forms","fairy"]	[0.75,0.8660254038]
# ["forms","female"]	[0.4,0.5773502692]
# ["forms","for"]	[0.1666666667,0.2886751346]
# ["forms","general"]	[0.4,0.5773502692]
# ["forms","george"]	[0.4,0.5773502692]
# ["forms","government"]	[0.1666666667,0.2886751346]
# ["forms","in"]	[0.1111111111,0.2182178902]
# ["forms","limited"]	[0.4,0.5773502692]
# ["forms","narrative"]	[0.4,0.5773502692]
# ["forms","of"]	[0.125,0.298142397]
# ["forms","religious"]	[0.1666666667,0.2886751346]
# ["forms","sea"]	[0.1666666667,0.2886751346]
# ["forms","study"]	[0.25,0.4364357805]
# ["forms","tales"]	[0.75,0.8660254038]
# ["forms","the"]	[0.25,0.4364357805]
# ["forms","wales"]	[0.1666666667,0.2886751346]
# ["general","a"]	[0.1071428571,0.2886751346]
# ["general","bill"]	[0.1428571429,0.25]
# ["general","biography"]	[0.6,0.75]
# ["general","by"]	[0.1428571429,0.25]
# ["general","case"]	[0.2222222222,0.377964473]
# ["general","child's"]	[0.1428571429,0.25]
# ["general","christmas"]	[0.1428571429,0.25]
# ["general","circumstantial"]	[0.3333333333,0.5]
# ["general","city"]	[0.1428571429,0.25]
# ["general","collection"]	[0.2857142857,0.4472135955]
# ["general","establishing"]	[0.1428571429,0.25]
# ["general","fairy"]	[0.3333333333,0.5]
# ["general","female"]	[0.3333333333,0.5]
# ["general","for"]	[0.1428571429,0.25]
# ["general","forms"]	[0.4,0.5773502692]
# ["general","george"]	[0.6,0.75]
# ["general","government"]	[0.1428571429,0.25]
# ["general","in"]	[0.1,0.1889822365]
# ["general","limited"]	[0.3333333333,0.5]
# ["general","narrative"]	[0.3333333333,0.5]
# ["general","of"]	[0.1875,0.3872983346]
# ["general","religious"]	[0.1428571429,0.25]
# ["general","sea"]	[0.1428571429,0.25]
# ["general","study"]	[0.2222222222,0.377964473]
# ["general","tales"]	[0.3333333333,0.5]
# ["general","the"]	[0.2222222222,0.377964473]
# ["general","wales"]	[0.1428571429,0.25]
# ["george","a"]	[0.1071428571,0.2886751346]
# ["george","bill"]	[0.1428571429,0.25]
# ["george","biography"]	[0.6,0.75]
# ["george","by"]	[0.1428571429,0.25]
# ["george","case"]	[0.2222222222,0.377964473]
# ["george","child's"]	[0.1428571429,0.25]
# ["george","christmas"]	[0.1428571429,0.25]
# ["george","circumstantial"]	[0.3333333333,0.5]
# ["george","city"]	[0.1428571429,0.25]
# ["george","collection"]	[0.2857142857,0.4472135955]
# ["george","establishing"]	[0.1428571429,0.25]
# ["george","fairy"]	[0.3333333333,0.5]
# ["george","female"]	[0.3333333333,0.5]
# ["george","for"]	[0.1428571429,0.25]
# ["george","forms"]	[0.4,0.5773502692]
# ["george","general"]	[0.6,0.75]
# ["george","government"]	[0.1428571429,0.25]
# ["george","in"]	[0.1,0.1889822365]
# ["george","limited"]	[0.3333333333,0.5]
# ["george","narrative"]	[0.3333333333,0.5]
# ["george","of"]	[0.1875,0.3872983346]
# ["george","religious"]	[0.1428571429,0.25]
# ["george","sea"]	[0.1428571429,0.25]
# ["george","study"]	[0.2222222222,0.377964473]
# ["george","tales"]	[0.3333333333,0.5]
# ["george","the"]	[0.2222222222,0.377964473]
# ["george","wales"]	[0.1428571429,0.25]
# ["government","a"]	[0.1071428571,0.2886751346]
# ["government","bill"]	[0.1428571429,0.25]
# ["government","biography"]	[0.1428571429,0.25]
# ["government","by"]	[0.1428571429,0.25]
# ["government","case"]	[0.375,0.5669467095]
# ["government","child's"]	[0.3333333333,0.5]
# ["government","christmas"]	[0.3333333333,0.5]
# ["government","circumstantial"]	[0.1428571429,0.25]
# ["government","city"]	[0.1428571429,0.25]
# ["government","collection"]	[0.125,0.2236067977]
# ["government","establishing"]	[0.1428571429,0.25]
# ["government","fairy"]	[0.1428571429,0.25]
# ["government","female"]	[0.6,0.75]
# ["government","for"]	[0.1428571429,0.25]
# ["government","forms"]	[0.1666666667,0.2886751346]
# ["government","general"]	[0.1428571429,0.25]
# ["government","george"]	[0.1428571429,0.25]
# ["government","in"]	[0.375,0.5669467095]
# ["government","limited"]	[0.6,0.75]
# ["government","narrative"]	[0.1428571429,0.25]
# ["government","of"]	[0.1875,0.3872983346]
# ["government","religious"]	[0.1428571429,0.25]
# ["government","sea"]	[0.1428571429,0.25]
# ["government","study"]	[0.375,0.5669467095]
# ["government","tales"]	[0.1428571429,0.25]
# ["government","the"]	[0.1,0.1889822365]
# ["government","wales"]	[0.3333333333,0.5]
# ["in","a"]	[0.2142857143,0.4364357805]
# ["in","bill"]	[0.1,0.1889822365]
# ["in","biography"]	[0.1,0.1889822365]
# ["in","by"]	[0.1,0.1889822365]
# ["in","case"]	[0.2727272727,0.4285714286]
# ["in","child's"]	[0.375,0.5669467095]
# ["in","christmas"]	[0.375,0.5669467095]
# ["in","circumstantial"]	[0.1,0.1889822365]
# ["in","city"]	[0.1,0.1889822365]
# ["in","collection"]	[0.0909090909,0.1690308509]
# ["in","establishing"]	[0.1,0.1889822365]
# ["in","fairy"]	[0.1,0.1889822365]
# ["in","female"]	[0.375,0.5669467095]
# ["in","for"]	[0.1,0.1889822365]
# ["in","forms"]	[0.1111111111,0.2182178902]
# ["in","general"]	[0.1,0.1889822365]
# ["in","george"]	[0.1,0.1889822365]
# ["in","government"]	[0.375,0.5669467095]
# ["in","limited"]	[0.375,0.5669467095]
# ["in","narrative"]	[0.1,0.1889822365]
# ["in","of"]	[0.1578947368,0.2927700219]
# ["in","religious"]	[0.1,0.1889822365]
# ["in","sea"]	[0.1,0.1889822365]
# ["in","study"]	[0.2727272727,0.4285714286]
# ["in","tales"]	[0.1,0.1889822365]
# ["in","the"]	[0.0769230769,0.1428571429]
# ["in","wales"]	[0.375,0.5669467095]
# ["limited","a"]	[0.1071428571,0.2886751346]
# ["limited","bill"]	[0.1428571429,0.25]
# ["limited","biography"]	[0.3333333333,0.5]
# ["limited","by"]	[0.1428571429,0.25]
# ["limited","case"]	[0.375,0.5669467095]
# ["limited","child's"]	[0.1428571429,0.25]
# ["limited","christmas"]	[0.1428571429,0.25]
# ["limited","circumstantial"]	[0.3333333333,0.5]
# ["limited","city"]	[0.1428571429,0.25]
# ["limited","collection"]	[0.2857142857,0.4472135955]
# ["limited","establishing"]	[0.1428571429,0.25]
# ["limited","fairy"]	[0.3333333333,0.5]
# ["limited","female"]	[1.0,1.0]
# ["limited","for"]	[0.1428571429,0.25]
# ["limited","forms"]	[0.4,0.5773502692]
# ["limited","general"]	[0.3333333333,0.5]
# ["limited","george"]	[0.3333333333,0.5]
# ["limited","government"]	[0.6,0.75]
# ["limited","in"]	[0.375,0.5669467095]
# ["limited","narrative"]	[0.3333333333,0.5]
# ["limited","of"]	[0.1875,0.3872983346]
# ["limited","religious"]	[0.1428571429,0.25]
# ["limited","sea"]	[0.1428571429,0.25]
# ["limited","study"]	[0.375,0.5669467095]
# ["limited","tales"]	[0.3333333333,0.5]
# ["limited","the"]	[0.2222222222,0.377964473]
# ["limited","wales"]	[0.1428571429,0.25]
# ["narrative","a"]	[0.1071428571,0.2886751346]
# ["narrative","bill"]	[0.1428571429,0.25]
# ["narrative","biography"]	[0.3333333333,0.5]
# ["narrative","by"]	[0.3333333333,0.5]
# ["narrative","case"]	[0.2222222222,0.377964473]
# ["narrative","child's"]	[0.1428571429,0.25]
# ["narrative","christmas"]	[0.1428571429,0.25]
# ["narrative","circumstantial"]	[0.6,0.75]
# ["narrative","city"]	[0.3333333333,0.5]
# ["narrative","collection"]	[0.2857142857,0.4472135955]
# ["narrative","establishing"]	[0.1428571429,0.25]
# ["narrative","fairy"]	[0.3333333333,0.5]
# ["narrative","female"]	[0.3333333333,0.5]
# ["narrative","for"]	[0.1428571429,0.25]
# ["narrative","forms"]	[0.4,0.5773502692]
# ["narrative","general"]	[0.3333333333,0.5]
# ["narrative","george"]	[0.3333333333,0.5]
# ["narrative","government"]	[0.1428571429,0.25]
# ["narrative","in"]	[0.1,0.1889822365]
# ["narrative","limited"]	[0.3333333333,0.5]
# ["narrative","of"]	[0.1875,0.3872983346]
# ["narrative","religious"]	[0.1428571429,0.25]
# ["narrative","sea"]	[0.3333333333,0.5]
# ["narrative","study"]	[0.2222222222,0.377964473]
# ["narrative","tales"]	[0.3333333333,0.5]
# ["narrative","the"]	[0.375,0.5669467095]
# ["narrative","wales"]	[0.1428571429,0.25]
# ["of","a"]	[0.5,0.695665593]
# ["of","bill"]	[0.0555555556,0.1290994449]
# ["of","biography"]	[0.1875,0.3872983346]
# ["of","by"]	[0.1176470588,0.2581988897]
# ["of","case"]	[0.2222222222,0.3903600292]
# ["of","child's"]	[0.0555555556,0.1290994449]
# ["of","christmas"]	[0.0555555556,0.1290994449]
# ["of","circumstantial"]	[0.1875,0.3872983346]
# ["of","city"]	[0.1176470588,0.2581988897]
# ["of","collection"]	[0.25,0.4618802154]
# ["of","establishing"]	[0.0555555556,0.1290994449]
# ["of","fairy"]	[0.1875,0.3872983346]
# ["of","female"]	[0.1875,0.3872983346]
# ["of","for"]	[0.0555555556,0.1290994449]
# ["of","forms"]	[0.125,0.298142397]
# ["of","general"]	[0.1875,0.3872983346]
# ["of","george"]	[0.1875,0.3872983346]
# ["of","government"]	[0.1875,0.3872983346]
# ["of","in"]	[0.1578947368,0.2927700219]
# ["of","limited"]	[0.1875,0.3872983346]
# ["of","narrative"]	[0.1875,0.3872983346]
# ["of","religious"]	[0.0555555556,0.1290994449]
# ["of","sea"]	[0.1176470588,0.2581988897]
# ["of","study"]	[0.2222222222,0.3903600292]
# ["of","tales"]	[0.1875,0.3872983346]
# ["of","the"]	[0.1578947368,0.2927700219]
# ["of","wales"]	[0.0555555556,0.1290994449]
# ["religious","a"]	[0.1071428571,0.2886751346]
# ["religious","bill"]	[0.6,0.75]
# ["religious","biography"]	[0.1428571429,0.25]
# ["religious","by"]	[0.1428571429,0.25]
# ["religious","case"]	[0.1,0.1889822365]
# ["religious","child's"]	[0.1428571429,0.25]
# ["religious","christmas"]	[0.1428571429,0.25]
# ["religious","circumstantial"]	[0.1428571429,0.25]
# ["religious","city"]	[0.1428571429,0.25]
# ["religious","collection"]	[0.125,0.2236067977]
# ["religious","establishing"]	[0.6,0.75]
# ["religious","fairy"]	[0.1428571429,0.25]
# ["religious","female"]	[0.1428571429,0.25]
# ["religious","for"]	[0.6,0.75]
# ["religious","forms"]	[0.1666666667,0.2886751346]
# ["religious","general"]	[0.1428571429,0.25]
# ["religious","george"]	[0.1428571429,0.25]
# ["religious","government"]	[0.1428571429,0.25]
# ["religious","in"]	[0.1,0.1889822365]
# ["religious","limited"]	[0.1428571429,0.25]
# ["religious","narrative"]	[0.1428571429,0.25]
# ["religious","of"]	[0.0555555556,0.1290994449]
# ["religious","sea"]	[0.1428571429,0.25]
# ["religious","study"]	[0.1,0.1889822365]
# ["religious","tales"]	[0.1428571429,0.25]
# ["religious","the"]	[0.1,0.1889822365]
# ["religious","wales"]	[0.1428571429,0.25]
# ["sea","a"]	[0.1071428571,0.2886751346]
# ["sea","bill"]	[0.1428571429,0.25]
# ["sea","biography"]	[0.1428571429,0.25]
# ["sea","by"]	[0.6,0.75]
# ["sea","case"]	[0.1,0.1889822365]
# ["sea","child's"]	[0.1428571429,0.25]
# ["sea","christmas"]	[0.1428571429,0.25]
# ["sea","circumstantial"]	[0.3333333333,0.5]
# ["sea","city"]	[0.6,0.75]
# ["sea","collection"]	[0.125,0.2236067977]
# ["sea","establishing"]	[0.1428571429,0.25]
# ["sea","fairy"]	[0.1428571429,0.25]
# ["sea","female"]	[0.1428571429,0.25]
# ["sea","for"]	[0.1428571429,0.25]
# ["sea","forms"]	[0.1666666667,0.2886751346]
# ["sea","general"]	[0.1428571429,0.25]
# ["sea","george"]	[0.1428571429,0.25]
# ["sea","government"]	[0.1428571429,0.25]
# ["sea","in"]	[0.1,0.1889822365]
# ["sea","limited"]	[0.1428571429,0.25]
# ["sea","narrative"]	[0.3333333333,0.5]
# ["sea","of"]	[0.1176470588,0.2581988897]
# ["sea","religious"]	[0.1428571429,0.25]
# ["sea","study"]	[0.1,0.1889822365]
# ["sea","tales"]	[0.1428571429,0.25]
# ["sea","the"]	[0.375,0.5669467095]
# ["sea","wales"]	[0.1428571429,0.25]
# ["study","a"]	[0.2142857143,0.4364357805]
# ["study","bill"]	[0.1,0.1889822365]
# ["study","biography"]	[0.2222222222,0.377964473]
# ["study","by"]	[0.1,0.1889822365]
# ["study","case"]	[0.75,0.8571428571]
# ["study","child's"]	[0.2222222222,0.377964473]
# ["study","christmas"]	[0.2222222222,0.377964473]
# ["study","circumstantial"]	[0.2222222222,0.377964473]
# ["study","city"]	[0.1,0.1889822365]
# ["study","collection"]	[0.2,0.3380617019]
# ["study","establishing"]	[0.1,0.1889822365]
# ["study","fairy"]	[0.2222222222,0.377964473]
# ["study","female"]	[0.375,0.5669467095]
# ["study","for"]	[0.1,0.1889822365]
# ["study","forms"]	[0.25,0.4364357805]
# ["study","general"]	[0.2222222222,0.377964473]
# ["study","george"]	[0.2222222222,0.377964473]
# ["study","government"]	[0.375,0.5669467095]
# ["study","in"]	[0.2727272727,0.4285714286]
# ["study","limited"]	[0.375,0.5669467095]
# ["study","narrative"]	[0.2222222222,0.377964473]
# ["study","of"]	[0.2222222222,0.3903600292]
# ["study","religious"]	[0.1,0.1889822365]
# ["study","sea"]	[0.1,0.1889822365]
# ["study","tales"]	[0.2222222222,0.377964473]
# ["study","the"]	[0.1666666667,0.2857142857]
# ["study","wales"]	[0.2222222222,0.377964473]
# ["tales","a"]	[0.1071428571,0.2886751346]
# ["tales","bill"]	[0.1428571429,0.25]
# ["tales","biography"]	[0.3333333333,0.5]
# ["tales","by"]	[0.1428571429,0.25]
# ["tales","case"]	[0.2222222222,0.377964473]
# ["tales","child's"]	[0.1428571429,0.25]
# ["tales","christmas"]	[0.1428571429,0.25]
# ["tales","circumstantial"]	[0.3333333333,0.5]
# ["tales","city"]	[0.1428571429,0.25]
# ["tales","collection"]	[0.5,0.6708203932]
# ["tales","establishing"]	[0.1428571429,0.25]
# ["tales","fairy"]	[0.6,0.75]
# ["tales","female"]	[0.3333333333,0.5]
# ["tales","for"]	[0.1428571429,0.25]
# ["tales","forms"]	[0.75,0.8660254038]
# ["tales","general"]	[0.3333333333,0.5]
# ["tales","george"]	[0.3333333333,0.5]
# ["tales","government"]	[0.1428571429,0.25]
# ["tales","in"]	[0.1,0.1889822365]
# ["tales","limited"]	[0.3333333333,0.5]
# ["tales","narrative"]	[0.3333333333,0.5]
# ["tales","of"]	[0.1875,0.3872983346]
# ["tales","religious"]	[0.1428571429,0.25]
# ["tales","sea"]	[0.1428571429,0.25]
# ["tales","study"]	[0.2222222222,0.377964473]
# ["tales","the"]	[0.2222222222,0.377964473]
# ["tales","wales"]	[0.1428571429,0.25]
# ["the","a"]	[0.2142857143,0.4364357805]
# ["the","bill"]	[0.1,0.1889822365]
# ["the","biography"]	[0.2222222222,0.377964473]
# ["the","by"]	[0.375,0.5669467095]
# ["the","case"]	[0.1666666667,0.2857142857]
# ["the","child's"]	[0.1,0.1889822365]
# ["the","christmas"]	[0.1,0.1889822365]
# ["the","circumstantial"]	[0.375,0.5669467095]
# ["the","city"]	[0.375,0.5669467095]
# ["the","collection"]	[0.2,0.3380617019]
# ["the","establishing"]	[0.1,0.1889822365]
# ["the","fairy"]	[0.2222222222,0.377964473]
# ["the","female"]	[0.2222222222,0.377964473]
# ["the","for"]	[0.1,0.1889822365]
# ["the","forms"]	[0.25,0.4364357805]
# ["the","general"]	[0.2222222222,0.377964473]
# ["the","george"]	[0.2222222222,0.377964473]
# ["the","government"]	[0.1,0.1889822365]
# ["the","in"]	[0.0769230769,0.1428571429]
# ["the","limited"]	[0.2222222222,0.377964473]
# ["the","narrative"]	[0.375,0.5669467095]
# ["the","of"]	[0.1578947368,0.2927700219]
# ["the","religious"]	[0.1,0.1889822365]
# ["the","sea"]	[0.375,0.5669467095]
# ["the","study"]	[0.1666666667,0.2857142857]
# ["the","tales"]	[0.2222222222,0.377964473]
# ["the","wales"]	[0.1,0.1889822365]
# ["wales","a"]	[0.1071428571,0.2886751346]
# ["wales","bill"]	[0.1428571429,0.25]
# ["wales","biography"]	[0.1428571429,0.25]
# ["wales","by"]	[0.1428571429,0.25]
# ["wales","case"]	[0.2222222222,0.377964473]
# ["wales","child's"]	[0.6,0.75]
# ["wales","christmas"]	[0.6,0.75]
# ["wales","circumstantial"]	[0.1428571429,0.25]
# ["wales","city"]	[0.1428571429,0.25]
# ["wales","collection"]	[0.125,0.2236067977]
# ["wales","establishing"]	[0.1428571429,0.25]
# ["wales","fairy"]	[0.1428571429,0.25]
# ["wales","female"]	[0.1428571429,0.25]
# ["wales","for"]	[0.1428571429,0.25]
# ["wales","forms"]	[0.1666666667,0.2886751346]
# ["wales","general"]	[0.1428571429,0.25]
# ["wales","george"]	[0.1428571429,0.25]
# ["wales","government"]	[0.3333333333,0.5]
# ["wales","in"]	[0.375,0.5669467095]
# ["wales","limited"]	[0.1428571429,0.25]
# ["wales","narrative"]	[0.1428571429,0.25]
# ["wales","of"]	[0.0555555556,0.1290994449]
# ["wales","religious"]	[0.1428571429,0.25]
# ["wales","sea"]	[0.1428571429,0.25]
# ["wales","study"]	[0.2222222222,0.377964473]
# ["wales","tales"]	[0.1428571429,0.25]
# ["wales","the"]	[0.1,0.1889822365]

# %%
###########################################################################
# Document similarity from inverted index
###########################################################################

# !hdfs dfs -rm -r systems_test_doc_similarity_2

#Local works
#!python similarity.py -r local systems_test_inv_index_2 > systems_test_doc_similarity_2   

#Hadoop mode for docker container
# !python similarity.py -r hadoop systems_test_inv_index_2 > systems_test_doc_similarity_2   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python similarity.py -r hadoop systems_test_inv_index_2 > systems_test_inv_index_2 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_doc_similarity_2': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/similarity.root.20170616.213450.191961
# Copying local files to hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213450.191961/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob3661620423641772507.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0038
#   Submitted application application_1497107873528_0038
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0038/
#   Running job: job_1497107873528_0038
#   Job job_1497107873528_0038 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0038 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213450.191961/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=206
# 	File Output Format Counters
# 		Bytes Written=428
# 	File System Counters
# 		FILE: Number of bytes read=742
# 		FILE: Number of bytes written=357223
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=552
# 		HDFS: Number of bytes written=428
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=7557120
# 		Total megabyte-seconds taken by all reduce tasks=3262464
# 		Total time spent by all map tasks (ms)=7380
# 		Total time spent by all maps in occupied slots (ms)=7380
# 		Total time spent by all reduce tasks (ms)=3186
# 		Total time spent by all reduces in occupied slots (ms)=3186
# 		Total vcore-seconds taken by all map tasks=7380
# 		Total vcore-seconds taken by all reduce tasks=3186
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1790
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=43
# 		Input split bytes=346
# 		Map input records=4
# 		Map output bytes=704
# 		Map output materialized bytes=748
# 		Map output records=16
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=759037952
# 		Reduce input groups=12
# 		Reduce input records=16
# 		Reduce output records=12
# 		Reduce shuffle bytes=748
# 		Shuffled Maps =2
# 		Spilled Records=32
# 		Total committed heap usage (bytes)=638058496
# 		Virtual memory (bytes) snapshot=4111200256
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213450.191961/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213450.191961...
# Removing temp directory /tmp/similarity.root.20170616.213450.191961...

# %%
# !cat systems_test_doc_similarity_2

# %%
###########################################################################
# Document similarity from inverted index
###########################################################################

# !hdfs dfs -rm -r systems_test_doc_similarity_3

#Local works
#!python similarity.py -r local systems_test_inv_index_3 > systems_test_doc_similarity_3   

#Hadoop mode for docker container
# !python similarity.py -r hadoop systems_test_inv_index_3 > systems_test_doc_similarity_3   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python similarity.py -r hadoop systems_test_inv_index_3 > systems_test_inv_index_3 \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# rm: `systems_test_doc_similarity_3': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/similarity.root.20170616.213603.601365
# Copying local files to hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213603.601365/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob5249897433943686869.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497107873528_0039
#   Submitted application application_1497107873528_0039
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497107873528_0039/
#   Running job: job_1497107873528_0039
#   Job job_1497107873528_0039 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497107873528_0039 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213603.601365/output
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=167
# 	File Output Format Counters
# 		Bytes Written=228
# 	File System Counters
# 		FILE: Number of bytes read=436
# 		FILE: Number of bytes written=356611
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=513
# 		HDFS: Number of bytes written=228
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=7988224
# 		Total megabyte-seconds taken by all reduce tasks=3070976
# 		Total time spent by all map tasks (ms)=7801
# 		Total time spent by all maps in occupied slots (ms)=7801
# 		Total time spent by all reduce tasks (ms)=2999
# 		Total time spent by all reduces in occupied slots (ms)=2999
# 		Total vcore-seconds taken by all map tasks=7801
# 		Total vcore-seconds taken by all reduce tasks=2999
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1940
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=68
# 		Input split bytes=346
# 		Map input records=5
# 		Map output bytes=410
# 		Map output materialized bytes=442
# 		Map output records=10
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=753205248
# 		Reduce input groups=6
# 		Reduce input records=10
# 		Reduce output records=6
# 		Reduce shuffle bytes=442
# 		Shuffled Maps =2
# 		Spilled Records=20
# 		Total committed heap usage (bytes)=638058496
# 		Virtual memory (bytes) snapshot=4081913856
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213603.601365/output...
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/similarity.root.20170616.213603.601365...
# Removing temp directory /tmp/similarity.root.20170616.213603.601365...

# %%
# !cat systems_test_doc_similarity_3

# %% [markdown]
# ## 3.  HW5.4.1 <a name="5.4.1"></a>Full-scale experiment: EDA of Google n-grams dataset (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Do some EDA on this dataset using mrjob, e.g.,
#
# - A. Longest 5-gram (number of characters)
# - B. Top 10 most frequent words (please use the count information), i.e., unigrams
# - C. 20 Most/Least densely appearing words (count/pages_count) sorted in decreasing order of relative frequency
# - D. Distribution of 5-gram sizes (character length).  E.g., count (using the count field) up how many times a 5-gram of 50 characters shows up. Plot the data graphically using a histogram.

# %% [markdown]
# ### HW5.4.1 - A. Longest 5-gram (number of characters)

# %%
test_list = ['a', 'b', 'c']

test = "testword"
len(test)
# Out:
# 8

# %%
# %%writefile longest5gram.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import numpy as np

class longest5gram(MRJob):
    
    # START STUDENT CODE 5.4.1.A
         
    
    def steps(self):
        return [
            MRStep(mapper=self.mapper,
                   reducer=self.reducer
                  )
        ]
    
    def mapper(self, _, line):

        #get the list of tokens in the 5-gram
        token_list = line.strip().lower().split()[:-3]

        #instantiate counter to hold the five-gram length
        five_gram_len = 0

        #For each token, increment the five-gram length holder    
        for token in token_list:
            five_gram_len += len(token)

        yield None, five_gram_len
        
    def reducer(self, key, five_gram_len):
        yield None, max(five_gram_len)
    # END STUDENT CODE 5.4.1.A
    
if __name__ == '__main__':
    longest5gram.run()
# Out:
# Overwriting longest5gram.py

# %% [markdown]
# __On test data set:__

# %%
#Local works
#!python longest5gram.py -r local googlebooks-eng-all-5gram-20090715-0-filtered.txt > longest_5gram_test   

#Hadoop mode for docker container
# !python longest5gram.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt > longest_5gram_test   

#Hadoop works when virtual python environment loaded up to hadoop is specified
#!python longest5gram.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt > longest_5gram_test \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/longest5gram.root.20170618.223325.748529
# Copying local files to hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob6415832985651518147.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0009
#   Submitted application application_1497814303217_0009
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0009/
#   Running job: job_1497814303217_0009
#   Job job_1497814303217_0009 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#   Task Id : attempt_1497814303217_0009_r_000000_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:244)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:164)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:415)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1693)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
#
#   Task Id : attempt_1497814303217_0009_r_000000_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:244)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:164)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:415)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1693)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
#
#   Task Id : attempt_1497814303217_0009_r_000000_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:244)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:164)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:415)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1693)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
#
#    map 100% reduce 100%
#   Job job_1497814303217_0009 failed with state FAILED due to: Task failed task_1497814303217_0009_r_000000
# Job failed as tasks failed. failedMaps:0 failedReduces:1
#
#   Job not successful!
#   Streaming Command Failed!
# Counters: 37
# 	File Input Format Counters
# 		Bytes Read=11448710
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=3352144
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=11449112
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=6
# 		HDFS: Number of write operations=0
# 	Job Counters
# 		Data-local map tasks=2
# 		Failed reduce tasks=4
# 		Launched map tasks=2
# 		Launched reduce tasks=4
# 		Total megabyte-seconds taken by all map tasks=8724480
# 		Total megabyte-seconds taken by all reduce tasks=13417472
# 		Total time spent by all map tasks (ms)=8520
# 		Total time spent by all maps in occupied slots (ms)=8520
# 		Total time spent by all reduce tasks (ms)=13103
# 		Total time spent by all reduces in occupied slots (ms)=13103
# 		Total vcore-seconds taken by all map tasks=8520
# 		Total vcore-seconds taken by all reduce tasks=13103
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3290
# 		Combine input records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=38
# 		Input split bytes=402
# 		Map input records=311614
# 		Map output bytes=2492884
# 		Map output materialized bytes=3116124
# 		Map output records=311614
# 		Merged Map outputs=0
# 		Physical memory (bytes) snapshot=599662592
# 		Spilled Records=311614
# 		Total committed heap usage (bytes)=495976448
# 		Virtual memory (bytes) snapshot=2712428544
# Scanning logs for probable cause of failure...
# Looking for history log in hdfs:///tmp/hadoop-yarn/staging...
# Looking for history log in /var/log/hadoop-yarn...
# Probable cause of failure:
#
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:244)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:164)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:415)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1693)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:158)
#
# Step 1 of 1 failed: Command '['/usr/bin/hadoop', 'jar', '/usr/lib/hadoop-mapreduce/hadoop-streaming.jar', '-files', 'hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/files/longest5gram.py#longest5gram.py,hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/files/mrjob.zip#mrjob.zip,hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/files/setup-wrapper.sh#setup-wrapper.sh', '-input', 'hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/files/googlebooks-eng-all-5gram-20090715-0-filtered.txt', '-output', 'hdfs:///user/root/tmp/mrjob/longest5gram.root.20170618.223325.748529/output', '-mapper', 'sh -ex setup-wrapper.sh /opt/anaconda/bin/python longest5gram.py --step-num=0 --mapper', '-reducer', 'sh -ex setup-wrapper.sh /opt/anaconda/bin/python longest5gram.py --step-num=0 --reducer']' returned non-zero exit status 256

# %%
# !cat longest_5gram_test
# Out:
# null	54

# %% [markdown]
# __On full data set:__

# %% [markdown]
# ## Report Stats:
# ## example:
# ## Longest 5grams MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 107.0s ~= 2 minutes
#     Reduce tasks = 16
#
# __Step 2:__
#
#     RUNNING for 108.8s ~= 2 minutes
#     Reduce tasks = 1

# %% [markdown]
# ### HW5.4.1 - B. Top 10 most frequent words

# %% [markdown]
# ### Get rough percentiles for the partition file
# A wordcount file for googlebooks-eng-all-5gram-20090715-0-filtered.txt is saved here: most_common_words_dist_sampling
#
# The partition file defines the breakpoints that we use to define which words go to which partitions. Here, I've looked at a sorted version of the first google n-grams file just to estimate the breakpoints that would roughly yield evenly sized partitions.

# %%
#How many lines does the file have?
# !wc -l most_common_words_dist_sampling

#90th percentile
# !sed '3600q;d' most_common_words_dist_sampling
#80th
# !sed '7200q;d' most_common_words_dist_sampling
#70th
# !sed '10800q;d' most_common_words_dist_sampling
#60th
# !sed '14400q;d' most_common_words_dist_sampling
#50th
# !sed '18000q;d' most_common_words_dist_sampling
#40th
# !sed '21600q;d' most_common_words_dist_sampling
#30th
# !sed '25200q;d' most_common_words_dist_sampling
#20th
# !sed '28800q;d' most_common_words_dist_sampling
#10th
# !sed '32400q;d' most_common_words_dist_sampling
# Out:
# 36353 most_common_words_dist_sampling
# "tall"	34
# "differed"	12
# "hog"	6
# "assigns"	3
# "veda"	2
# "abutment"	1
# "abolitionists"	1
# "wrapper"	1
# "relinquishes"	1

# %%
# %%writefile mostFrequentWords_combined.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol
from mrjob.protocol import RawProtocol
from operator import itemgetter
import numpy as np


class mostFrequentWords(MRJob):
        
    #****************************************************
    # Allows values to be treated as keys
    MRJob.SORT_VALUES = True 
    
    # The protocols are critical. It will not work without these:
    INPUT_PROTOCOL = RawValueProtocol
    INTERNAL_PROTOCOL = RawProtocol
    OUTPUT_PROTOCOL = RawProtocol
     
    def __init__(self, *args, **kwargs):
        super(mostFrequentWords, self).__init__(*args, **kwargs)
        self.N = 30
        self.NUM_REDUCERS = 7
    #****************************************************


    # START STUDENT CODE 5.4.1.B

    def mapper(self, _, line):

        #get the list of tokens in the 5-gram
        token_list = line.strip().lower().split()[:-3]

        #emit each token and a 1   
        for token in token_list:
            yield token, str(1)

    def combiner(self, token, count):
        #just do local sums before passing to reducer
        count_sum = 0
        for item in count:
            count_sum += int(item)
        yield token, str(count_sum)            
            
    def reducer(self, token, count):
        count_sum = 0
        for item in count:
            count_sum += int(item)
        yield token, str(count_sum)
    
    #Implement total sort with ordered partitions
    def mapper_partitioner_init(self):
        
        #Function to hash keys
        def makeKeyHash(key, num_reducers):
            byteof = lambda char: int(format(ord(char), 'b'), 2)
            current_hash = 0
            for c in key:
                current_hash = (current_hash * 31 + byteof(c))
            return current_hash % num_reducers
        
        # get the keys: printable ascii characters, starting with 'A'
        keys = [str(unichr(i)) for i in range(65,65+self.NUM_REDUCERS)]
        partitions = []
        
        #Hash each key and link the key to its hashed int value
        for key in keys:
            partitions.append([key, makeKeyHash(key, self.NUM_REDUCERS)])

        #This step re-sorts so that the keys are 'out of order', but the partitions are 'ordered'
        parts = sorted(partitions,key=itemgetter(1))
        self.partition_keys = list(np.array(parts)[:,0])
        
        #NC Note - need to write a separate partition file that mirrors the distribution of your data.
        #Want to end up with roughly equi-sized partitions.
        #The example in the total sort code just assumes a uniform distribution.
        #self.partition_file = np.arange(0,self.N,self.N/(self.NUM_REDUCERS))[::-1]
        #You can mess with the breakpoints here to get evenly sized partitions.
        #Right now, I'm just doing these breakpoints by trial and error to try and get closer to evenly sized partitions.
        #A big improvement would be to make these breakpoints in a more sophisticated way to get evenly sized partitions.
        #Action item 1
        self.partition_file = np.array([34, 12, 6, 3, 2, 1, 0])
        
    #Read line and assign partition key to each line based on the value
    def mapper_partition(self, key, value):

        # Prepend the approriate key by finding the bucket, and using the index to fetch the key.
        #Loop over number of reducers
        for idx in xrange(self.NUM_REDUCERS):
            if float(value) > self.partition_file[idx]:
                #Need to emit the partition key here to leverage the hadoop shuffle phase.
                yield str(self.partition_keys[idx]),key+"\t"+value
                break
       
            
    def reducer_sort(self,key,value):
        for v in value:
            #This emits the partition key for illustration
            #yield key,v
            #This omits the partition key from the output
            yield None, v
    
    
    def steps(self):

        
        JOBCONF_STEP1 = {
            'stream.num.map.output.key.fields':3,
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':"\t",
            'mapreduce.partition.keypartitioner.options':'-k1,1',
            'mapreduce.partition.keycomparator.options':'-k3,3nr -k2,2',
            'mapred.reduce.tasks': self.NUM_REDUCERS,
            'partitioner':'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
        }
        
        return [
            MRStep(mapper=self.mapper,
                   combiner=self.combiner,
                   reducer=self.reducer),
            MRStep(jobconf=JOBCONF_STEP1,
                    mapper_init=self.mapper_partitioner_init,
                    mapper=self.mapper_partition,
                    reducer=self.reducer_sort
                  )
        ]
     
        
    # END STUDENT CODE 5.4.1.B
        
        
if __name__ == '__main__':
    mostFrequentWords.run()
# Out:
# Overwriting mostFrequentWords_combined.py

# %%
# !hdfs dfs -rm -r /user/nwchen24/HW5_Phase2

#Hadoop mode for docker container
# !python mostFrequentWords_combined.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt\
    --output-dir='/user/nwchen24/HW5_Phase2'\
    --no-output
# Out:
# Deleted /user/nwchen24/HW5_Phase2
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/mostFrequentWords_combined.root.20170619.033149.019961
# Copying local files to hdfs:///user/root/tmp/mrjob/mostFrequentWords_combined.root.20170619.033149.019961/files/...
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob4507224969099200532.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0060
#   Submitted application application_1497814303217_0060
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0060/
#   Running job: job_1497814303217_0060
#   Job job_1497814303217_0060 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497814303217_0060 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/mostFrequentWords_combined.root.20170619.033149.019961/step-output/0000
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=11448710
# 	File Output Format Counters
# 		Bytes Written=404022
# 	File System Counters
# 		FILE: Number of bytes read=702613
# 		FILE: Number of bytes written=1762573
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=11449140
# 		HDFS: Number of bytes written=404022
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=16863232
# 		Total megabyte-seconds taken by all reduce tasks=3614720
# 		Total time spent by all map tasks (ms)=16468
# 		Total time spent by all maps in occupied slots (ms)=16468
# 		Total time spent by all reduce tasks (ms)=3530
# 		Total time spent by all reduces in occupied slots (ms)=3530
# 		Total vcore-seconds taken by all map tasks=16468
# 		Total vcore-seconds taken by all reduce tasks=3530
# 	Map-Reduce Framework
# 		CPU time spent (ms)=10990
# 		Combine input records=1558070
# 		Combine output records=54102
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=100
# 		Input split bytes=430
# 		Map input records=311614
# 		Map output bytes=13001260
# 		Map output materialized bytes=702619
# 		Map output records=1558070
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=812650496
# 		Reduce input groups=36353
# 		Reduce input records=54102
# 		Reduce output records=36353
# 		Reduce shuffle bytes=702619
# 		Shuffled Maps =2
# 		Spilled Records=108204
# 		Total committed heap usage (bytes)=808976384
# 		Virtual memory (bytes) snapshot=4116934656
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.reduce.tasks: mapreduce.job.reduces
# Running step 2 of 2...
#   mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob7490287286944136344.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0061
#   Submitted application application_1497814303217_0061
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0061/
#   Running job: job_1497814303217_0061
#   Job job_1497814303217_0061 running in uber mode : false
#    map 0% reduce 0%
#    map 50% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 14%
#    map 100% reduce 29%
#    map 100% reduce 43%
#    map 100% reduce 57%
#    map 100% reduce 71%
#    map 100% reduce 100%
#   Job job_1497814303217_0061 completed successfully
#   Output directory: hdfs:///user/nwchen24/HW5_Phase2
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=408118
# 	File Output Format Counters
# 		Bytes Written=440375
# 	File System Counters
# 		FILE: Number of bytes read=585829
# 		FILE: Number of bytes written=2245222
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=408492
# 		HDFS: Number of bytes written=440375
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=27
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=7
# 		Total megabyte-seconds taken by all map tasks=7673856
# 		Total megabyte-seconds taken by all reduce tasks=47434752
# 		Total time spent by all map tasks (ms)=7494
# 		Total time spent by all maps in occupied slots (ms)=7494
# 		Total time spent by all reduce tasks (ms)=46323
# 		Total time spent by all reduces in occupied slots (ms)=46323
# 		Total vcore-seconds taken by all map tasks=7494
# 		Total vcore-seconds taken by all reduce tasks=46323
# 	Map-Reduce Framework
# 		CPU time spent (ms)=12430
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=273
# 		Input split bytes=374
# 		Map input records=36353
# 		Map output bytes=513081
# 		Map output materialized bytes=585871
# 		Map output records=36353
# 		Merged Map outputs=14
# 		Physical memory (bytes) snapshot=1916108800
# 		Reduce input groups=36353
# 		Reduce input records=36353
# 		Reduce output records=36353
# 		Reduce shuffle bytes=585871
# 		Shuffled Maps =14
# 		Spilled Records=72706
# 		Total committed heap usage (bytes)=1449132032
# 		Virtual memory (bytes) snapshot=12299718656
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/mostFrequentWords_combined.root.20170619.033149.019961...
# Removing temp directory /tmp/mostFrequentWords_combined.root.20170619.033149.019961...

# %%
# !hdfs dfs -ls /user/nwchen24/HW5_Phase2

# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | wc -l
print "="*100
# Out:
# Found 8 items
# -rw-r--r--   1 root supergroup          0 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/_SUCCESS
# -rw-r--r--   1 root supergroup      43401 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00000
# -rw-r--r--   1 root supergroup      41672 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00001
# -rw-r--r--   1 root supergroup      38290 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00002
# -rw-r--r--   1 root supergroup      46983 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00003
# -rw-r--r--   1 root supergroup      31842 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00004
# -rw-r--r--   1 root supergroup      58195 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00005
# -rw-r--r--   1 root supergroup     179992 2017-06-19 03:32 /user/nwchen24/HW5_Phase2/part-00006
# the	146015
# of	96509
# to	64026
# a	41972
# in	41831
# cat: Unable to write to output stream.
# 3573
# ====================================================================================================
# acquire	34
# aimed	34
# alike	34
# amongst	34
# armies	34
# cat: Unable to write to output stream.
# 3326
# ====================================================================================================
# abuses	12
# admiral	12
# admiralty	12
# advancing	12
# advertising	12
# 3144
# ====================================================================================================
# abortion	6
# abscess	6
# accessed	6
# accompaniment	6
# accomplishing	6
# cat: Unable to write to output stream.
# 3956
# ====================================================================================================
# abate	3
# abbreviated	3
# abducted	3
# abel	3
# abhorrent	3
# cat: Unable to write to output stream.
# 2657
# ====================================================================================================
# abandons	2
# abated	2
# abbreviations	2
# abc	2
# abdicate	2
# cat: Unable to write to output stream.
# 4873
# ====================================================================================================
# aahperd	1
# aalborg	1
# aback	1
# abandoning	1
# abased	1
# cat: Unable to write to output stream.
# 14824
# ====================================================================================================

# %% [markdown]
# __On the full data set:__

# %% [markdown]
# ## Most frequent words MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 590.7s ~= 10 minutes
#     Launched map tasks=191
#     Launched reduce tasks=57
#
# __Step 2:__
#
#     RUNNING for 76.6s
#     Launched map tasks=110
#     Launched reduce tasks=16

# %% [markdown]
# ### HW5.4.1 - C. 20 Most/Least densely appearing words

# %%
# %%writefile mostLeastDenseWords.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-
from __future__ import division
import re
import mrjob
from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol
from mrjob.protocol import RawProtocol
from operator import itemgetter
import numpy as np

class mostLeastDenseWords(MRJob):
    
    # START STUDENT CODE 5.4.1.C
    
            
    #****************************************************
    # Allows values to be treated as keys
    MRJob.SORT_VALUES = True 
    
    # The protocols are critical. Total sort will not work without these:
    #Raw protocols require emitting strings from each phase
    INPUT_PROTOCOL = RawValueProtocol
    INTERNAL_PROTOCOL = RawProtocol
    OUTPUT_PROTOCOL = RawProtocol
     
    def __init__(self, *args, **kwargs):
        super(mostLeastDenseWords, self).__init__(*args, **kwargs)
        self.N = 30
        self.NUM_REDUCERS = 7
    #****************************************************

    def mapper(self, _, line):
        token_list = line.strip().lower().split()[:-3]
        pages = line.strip().lower().split()[-2]
        
        for token in token_list:
            yield token, pages+"\t"+str(1)
            #yield token, pages, str(1)

    #From the mapper, the combiner gets a generator object. This generator object contains all of the (page_sum \t length_sum) values output with each key.
    #The items in the generator object that the combiner gets must be split by the "\t" delimiter in order to separately access the two values output from the mapper.
    #Once split, you are left with a list containing the values output from the mapper [page_sum, length_sum]
    #You can then index this list to increment counts in the combiner.           
    def combiner(self, token, count):
        page_sum = 0
        length_sum = 0

        for item in count:
            item_list = item.split("\t")
            page_sum = page_sum + int(item_list[0])
            length_sum = length_sum + int(item_list[1])
        yield token, str(page_sum)+"\t"+str(length_sum)

    #From the mapper / combiner, the reducer gets a generator object. This generator object contains all of the (page_sum \t length_sum) values output with each key from the mapper / combiner.
    #It seems that the items in the generator object received by the reducer do NOT need to be split by the "\t" delimiter like we had to do in the combiner.
    #Thus, you can index the items in the generator object directly to increment page_sum and length_sum in the reducer
    def reducer(self, token, count):
        page_sum = 0
        length_sum = 0
        
        for item in count:
            page_sum = page_sum + int(item[0])
            length_sum = length_sum + int(item[1])
            
        yield token, str(length_sum / page_sum)
      
           
    #Implement total sort with ordered partitions
    def mapper_partitioner_init(self):
        
        #Function to hash keys
        def makeKeyHash(key, num_reducers):
            byteof = lambda char: int(format(ord(char), 'b'), 2)
            current_hash = 0
            for c in key:
                current_hash = (current_hash * 31 + byteof(c))
            return current_hash % num_reducers
        
        # get the keys: printable ascii characters, starting with 'A'
        keys = [str(unichr(i)) for i in range(65,65+self.NUM_REDUCERS)]
        partitions = []
        
        #Hash each key and link the key to its hashed int value
        for key in keys:
            partitions.append([key, makeKeyHash(key, self.NUM_REDUCERS)])

        #This step re-sorts so that the keys are 'out of order', but the partitions are 'ordered'
        parts = sorted(partitions,key=itemgetter(1))
        self.partition_keys = list(np.array(parts)[:,0])
        
        #NC Note - need to write a separate partition file that mirrors the distribution of your data.
        #Want to end up with roughly equi-sized partitions.
        #The example in the total sort code just assumes a uniform distribution.
        #self.partition_file = np.arange(0,self.N,self.N/(self.NUM_REDUCERS))[::-1]
        #You can mess with the breakpoints here to get evenly sized partitions.
        #Right now, I'm just doing these breakpoints by trial and error to try and get closer to evenly sized partitions.
        #A big improvement would be to make these breakpoints in a more sophisticated way to get evenly sized partitions.
        #Action item 1
        self.partition_file = np.array([7, 2, 1, 0.5, 0.25, 0.1, 0])
        
    #Read line and assign partition key to each line based on the value
    def mapper_partition(self, key, value):

        # Prepend the approriate key by finding the bucket, and using the index to fetch the key.
        #Loop over number of reducers
        for idx in xrange(self.NUM_REDUCERS):
            if float(value) > self.partition_file[idx]:
                #Need to emit the partition key here to leverage the hadoop shuffle phase.
                yield str(self.partition_keys[idx]),key+"\t"+value
                break
       
            
    def reducer_sort(self,key,value):
        for v in value:
            #This emits the partition key for illustration
            #yield key,v
            #This omits the partition key from the output
            yield None, v
    
    
    def steps(self):

        
        JOBCONF_STEP1 = {
            'stream.num.map.output.key.fields':2,
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':"\t",
            'mapreduce.partition.keypartitioner.options':'-k1,1',
            'mapred.reduce.tasks': self.NUM_REDUCERS,
            'partitioner':'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
        }
        
        JOBCONF_STEP2 = {
            'stream.num.map.output.key.fields':3,
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':"\t",
            'mapreduce.partition.keypartitioner.options':'-k1,1',
            'mapreduce.partition.keycomparator.options':'-k3,3nr -k2,2',
            'mapred.reduce.tasks': self.NUM_REDUCERS,
            'partitioner':'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP1,
                   mapper=self.mapper,
                   combiner=self.combiner,
                   reducer=self.reducer),
            MRStep(jobconf=JOBCONF_STEP2,
                    mapper_init=self.mapper_partitioner_init,
                    mapper=self.mapper_partition,
                    reducer=self.reducer_sort
                  )
        ]
          
    # END STUDENT CODE 5.4.1.C
        
if __name__ == '__main__':
    mostLeastDenseWords.run()
# Out:
# Overwriting mostLeastDenseWords.py

# %% [markdown]
# __On the test data set:__

# %%
# !hdfs dfs -rm -r /user/nwchen24/HW5_Phase2

#Hadoop mode with only first ten lines
#!python mostLeastDenseWords.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > total_sort_density_test

#!python mostLeastDenseWords.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt\
#    --output-dir='/user/nwchen24/HW5_Phase2'\
#    --no-output    

#Hadoop mode for docker container
# !python mostLeastDenseWords.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt\
    --output-dir='/user/nwchen24/HW5_Phase2'\
    --no-output
# Out:
# Deleted /user/nwchen24/HW5_Phase2
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/mostLeastDenseWords.root.20170619.052744.517632
# Copying local files to hdfs:///user/root/tmp/mrjob/mostLeastDenseWords.root.20170619.052744.517632/files/...
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.reduce.tasks: mapreduce.job.reduces
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# Running step 1 of 2...
#   mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob2327177079932846133.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0102
#   Submitted application application_1497814303217_0102
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0102/
#   Running job: job_1497814303217_0102
#   Job job_1497814303217_0102 running in uber mode : false
#    map 0% reduce 0%
#    map 33% reduce 0%
#    map 67% reduce 0%
#    map 83% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 14%
#    map 100% reduce 29%
#    map 100% reduce 43%
#    map 100% reduce 57%
#    map 100% reduce 71%
#    map 100% reduce 100%
#   Job job_1497814303217_0102 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/mostLeastDenseWords.root.20170619.052744.517632/step-output/0000
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=11448710
# 	File Output Format Counters
# 		Bytes Written=588205
# 	File System Counters
# 		FILE: Number of bytes read=913824
# 		FILE: Number of bytes written=2903435
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=11449126
# 		HDFS: Number of bytes written=588205
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=27
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=7
# 		Total megabyte-seconds taken by all map tasks=22061056
# 		Total megabyte-seconds taken by all reduce tasks=54513664
# 		Total time spent by all map tasks (ms)=21544
# 		Total time spent by all maps in occupied slots (ms)=21544
# 		Total time spent by all reduce tasks (ms)=53236
# 		Total time spent by all reduces in occupied slots (ms)=53236
# 		Total vcore-seconds taken by all map tasks=21544
# 		Total vcore-seconds taken by all reduce tasks=53236
# 	Map-Reduce Framework
# 		CPU time spent (ms)=24030
# 		Combine input records=1558070
# 		Combine output records=54102
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=416
# 		Input split bytes=416
# 		Map input records=311614
# 		Map output bytes=16647060
# 		Map output materialized bytes=913866
# 		Map output records=1558070
# 		Merged Map outputs=14
# 		Physical memory (bytes) snapshot=2024046592
# 		Reduce input groups=36353
# 		Reduce input records=54102
# 		Reduce output records=36353
# 		Reduce shuffle bytes=913866
# 		Shuffled Maps =14
# 		Spilled Records=108204
# 		Total committed heap usage (bytes)=1598029824
# 		Virtual memory (bytes) snapshot=12296867840
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.reduce.tasks: mapreduce.job.reduces
# Running step 2 of 2...
#   mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob555773764178634171.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 7
#   number of splits:7
#   Submitting tokens for job: job_1497814303217_0103
#   Submitted application application_1497814303217_0103
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0103/
#   Running job: job_1497814303217_0103
#   Job job_1497814303217_0103 running in uber mode : false
#    map 0% reduce 0%
#    map 14% reduce 0%
#    map 29% reduce 0%
#    map 43% reduce 0%
#    map 57% reduce 0%
#    map 71% reduce 0%
#    map 86% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 14%
#    map 100% reduce 29%
#    map 100% reduce 43%
#    map 100% reduce 57%
#    map 100% reduce 71%
#    map 100% reduce 86%
#    map 100% reduce 100%
#   Job job_1497814303217_0103 completed successfully
#   Output directory: hdfs:///user/nwchen24/HW5_Phase2
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=588205
# 	File Output Format Counters
# 		Bytes Written=587370
# 	File System Counters
# 		FILE: Number of bytes read=722244
# 		FILE: Number of bytes written=3113995
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=589458
# 		HDFS: Number of bytes written=587370
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=42
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=7
# 		Launched map tasks=7
# 		Launched reduce tasks=7
# 		Total megabyte-seconds taken by all map tasks=61283328
# 		Total megabyte-seconds taken by all reduce tasks=65550336
# 		Total time spent by all map tasks (ms)=59847
# 		Total time spent by all maps in occupied slots (ms)=59847
# 		Total time spent by all reduce tasks (ms)=64014
# 		Total time spent by all reduces in occupied slots (ms)=64014
# 		Total vcore-seconds taken by all map tasks=59847
# 		Total vcore-seconds taken by all reduce tasks=64014
# 	Map-Reduce Framework
# 		CPU time spent (ms)=21280
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=814
# 		Input split bytes=1253
# 		Map input records=36353
# 		Map output bytes=654786
# 		Map output materialized bytes=722496
# 		Map output records=33708
# 		Merged Map outputs=49
# 		Physical memory (bytes) snapshot=3398520832
# 		Reduce input groups=33708
# 		Reduce input records=33708
# 		Reduce output records=33708
# 		Reduce shuffle bytes=722496
# 		Shuffled Maps =49
# 		Spilled Records=67416
# 		Total committed heap usage (bytes)=2713714688
# 		Virtual memory (bytes) snapshot=19020529664
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/mostLeastDenseWords.root.20170619.052744.517632...
# Removing temp directory /tmp/mostLeastDenseWords.root.20170619.052744.517632...

# %%
# !hdfs dfs -ls /user/nwchen24/HW5_Phase2

# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | wc -l
print "="*100
# Out:
# Found 8 items
# -rw-r--r--   1 root supergroup          0 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/_SUCCESS
# -rw-r--r--   1 root supergroup       7909 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00000
# -rw-r--r--   1 root supergroup     100500 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00001
# -rw-r--r--   1 root supergroup     179228 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00002
# -rw-r--r--   1 root supergroup     178606 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00003
# -rw-r--r--   1 root supergroup      75818 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00004
# -rw-r--r--   1 root supergroup      42895 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00005
# -rw-r--r--   1 root supergroup       2414 2017-06-19 05:29 /user/nwchen24/HW5_Phase2/part-00006
# abjures	9.0
# accredited	9.0
# accumulate	9.0
# affirms	9.0
# aggrieved	9.0
# 566
# ====================================================================================================
# abed	7.0
# actin	7.0
# adheres	7.0
# ado	7.0
# alerted	7.0
# cat: Unable to write to output stream.
# 6463
# ====================================================================================================
# aalborg	2.0
# ab	2.0
# abandoning	2.0
# abierta	2.0
# abode	2.0
# cat: Unable to write to output stream.
# 10408
# ====================================================================================================
# aahperd	1.0
# abbot's	1.0
# abdication	1.0
# abhorreth	1.0
# abingdon	1.0
# cat: Unable to write to output stream.
# 9834
# ====================================================================================================
# abides	0.5
# abjured	0.5
# abnegation	0.5
# abnormalities	0.5
# abolitionists	0.5
# cat: Unable to write to output stream.
# 4050
# ====================================================================================================
# abased	0.25
# abbate	0.25
# abroade	0.25
# absolute	0.25
# accorded	0.25
# cat: Unable to write to output stream.
# 2271
# ====================================================================================================
# authentic	0.1
# bigger	0.1
# bishopric	0.1
# carve	0.1
# causing	0.1
# 116
# ====================================================================================================

# %% [markdown]
# __On the full data set:__

# %% [markdown]
# ## Word density MR stats
#
#     ec2_instance_type: m3.xlarge
#     num_ec2_instances: 15
#
# __Step 1:__
#
#     RUNNING for 649.2s  ~= 10 minutes
#     Launched map tasks=190
#     Launched reduce tasks=57
#
# __Step 2:__
#
#     RUNNING for 74.4s  ~= 1 minute
#     Launched map tasks=110
#     Launched reduce tasks=20

# %% [markdown]
# ### HW5.4.1 - D. Distribution of 5-gram sizes (character length)

# %%
# %%writefile distribution.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep

class distribution(MRJob):
    
    # START STUDENT CODE 5.4.1.D
    
    def steps(self):
        
        return [
            MRStep(mapper=self.mapper,
                   reducer=self.reducer
                  )
        ]
    
    def mapper(self, _, line):

        #get the list of tokens in the 5-gram
        token_list = line.strip().lower().split()[:-3]

        #instantiate counter to hold the five-gram length
        five_gram_len = 0

        #For each token, increment the five-gram length holder    
        for token in token_list:
            five_gram_len += len(token)

        yield five_gram_len, 1
        
    def reducer(self, key, five_gram_len_count):
        yield key, sum(five_gram_len_count)
        
    # END STUDENT CODE 5.4.1.D
    
if __name__ == '__main__':
    distribution.run()
# Out:
# Overwriting distribution.py

# %% [markdown]
# __On the test data set:__

# %%
# %reload_ext autoreload
# %autoreload 2
my_file = open('distribution.txt', 'w')
from distribution import distribution
mr_job = distribution(args=['googlebooks-eng-all-5gram-20090715-0-filtered.txt'])
with mr_job.make_runner() as runner:
    runner.run()
    for line in runner.stream_output():
        my_file.write(str(mr_job.parse_output_line(line)))
        my_file.write("\n")
        print mr_job.parse_output_line(line)

my_file.close()
# Out:
# (22, 25991)
# (23, 23405)
# (24, 20587)
# (25, 17257)
# (26, 14428)
# (27, 11340)
# (28, 9061)
# (29, 6950)
# (30, 5152)
# (31, 3871)
# (32, 2868)
# (33, 2027)
# (34, 1516)
# (35, 1027)
# (36, 756)
# (37, 476)
# (38, 337)
# (39, 263)
# (40, 195)
# (41, 113)
# (42, 87)
# (43, 51)
# (44, 33)
# (45, 31)
# (46, 13)
# (47, 10)
# (48, 9)
# (49, 8)
# (5, 1)
# (50, 2)
# (51, 4)
# (53, 2)
# (54, 2)
# (6, 1)
# (7, 1)
# (8, 3)
# (9, 22)
# (10, 94)
# (11, 309)
# (12, 1112)
# (13, 2859)
# (14, 5853)
# (15, 10200)
# (16, 15479)
# (17, 20108)
# (18, 24625)
# (19, 27333)
# (20, 28052)
# (21, 27690)

# %%
#Plot a histogram
import pandas as pd
import matplotlib.pyplot as plt

#create dict and DF that will hold the counts of the number of fivegrams of each length
fivegram_lengths_list = []
fivegram_counts_list = []


#Add the fivegram lengths and the number of fivegrams of that length to a dict
with open('distribution.txt', 'r') as f:
    for line in f:
        line_list = line.strip("\n").strip("(").strip(")").split(",")
        fivegram_lengths_list.append(int(line_list[0]))
        fivegram_counts_list.append(int(line_list[1]))

#Create a dataframe
fivegram_hist_df = pd.DataFrame({'Fivegram_len':fivegram_lengths_list, 'Count_of_Fivegrams':fivegram_counts_list})

#Sort the dataframe by fivegram length
fivegram_hist_df = fivegram_hist_df.sort_values('Fivegram_len')

#Plot density plot
plt.figure()
fivegram_hist_df.plot(x = 'Fivegram_len', y = 'Count_of_Fivegrams')
plt.show()

# %% [markdown]
# __On the full data set:__

# %% [markdown]
# ## Distribution MRJob stats
#
# __Step 1:__
#
#     RUNNING for 157.8s ~= 2.6 minutes
#     Launched map tasks=191
#     Launched reduce tasks=16
#
# __Step 2:__
#
#     RUNNING for 115.0s ~= 2 minutes
#     Launched map tasks=139
# 	Launched reduce tasks=1

# %%
# %matplotlib inline
import numpy as np
import pylab as pl

results_A = []
for line in open("5.3distributions/part-00000").readlines():
    line = line.strip()
    X,Y = line.split(",")
    results_A.append([int(X),int(Y)])

items = (np.array(results_A)[::-1].T)
fig = pl.figure(figsize=(17,7))
ax = pl.subplot(111)
width=0.8
ax.bar(range(len(items[0])), items[1], width=width)
ax.set_xticks(np.arange(len(items[0])) + width/2)
ax.set_xticklabels(items[0], rotation=90)



pl.title("Distributions of 5 Gram lengths")
pl.show()

# %% [markdown]
# ## 3.  HW5.4.2 <a name="5.4.2"></a>OPTIONAL Question: log-log plots (PHASE 2)
# [Back to Table of Contents](#TOC)
#
# Plot the log-log plot of the frequency distributuion of unigrams. Does it follow power law distribution?
#
# For more background see:
# - https://en.wikipedia.org/wiki/Log%E2%80%93log_plot
# - https://en.wikipedia.org/wiki/Power_law

# %% [markdown]
# ## 3.  HW5.5  <a name="5.5"></a> Synonym detection over 2Gig of Data with extra Preprocessing steps (HW5.3 plus some preprocessing)   (Phase 2)
# [Back to Table of Contents](#TOC)
#
# For the remainder of this assignment please feel free to eliminate stop words from your analysis

# %% [markdown]
# >There is also a corpus of stopwords, that is, high-frequency words like "the", "to" and "also" that we sometimes want to filter out of a document before further processing. Stopwords usually have little lexical content, and their presence in a text fails to distinguish it from other texts. Python's nltk comes with a prebuilt list of stopwords (see below). Using this stopword list filter out these tokens from your analysis and rerun the experiments in 5.5 and disucuss the results of using a stopword list and without using a stopword list.
#
# > from nltk.corpus import stopwords
#  stopwords.words('english')
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
# 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
# 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
# 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
# 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
# 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
# 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
# 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
# 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
# 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
# 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
# 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %% [markdown]
# ### 2: A large subset of the Google n-grams dataset as was described above
#
# For each HW 5.4 -5.5.1 Please unit test and system test your code with respect
# to SYSTEMS TEST DATASET and show the results.
# Please compute the expected answer by hand and show your hand calculations for the
# SYSTEMS TEST DATASET. Then show the results you get with your system.

# %% [markdown]
# In this part of the assignment we will focus on developing methods for detecting synonyms, using the Google 5-grams dataset. At a high level:
#
#
# 1. remove stopwords
# 2. get 10,0000 most frequent
# 3. get 1000 (9001-10000) features
# 3. build stripes
#
# To accomplish this you must script two main tasks using MRJob:
#
#
# __TASK (1)__ Build stripes for the most frequent 10,000 words using cooccurence information based on
# the words ranked from 9001,-10,000 as a basis/vocabulary (drop stopword-like terms),
# and output to a file in your bucket on s3 (bigram analysis, though the words are non-contiguous).
#
#
# __TASK (2)__ Using two (symmetric) comparison methods of your choice
# (e.g., correlations, distances, similarities), pairwise compare
# all stripes (vectors), and output to a file in your bucket on s3.
#
# #### Design notes for TASK (1)
# For this task you will be able to modify the pattern we used in HW 3.2
# (feel free to use the solution as reference). To total the word counts
# across the 5-grams, output the support from the mappers using the total
# order inversion pattern:
#
# <*word,count>
#
# to ensure that the support arrives before the cooccurrences.
#
# In addition to ensuring the determination of the total word counts,
# the mapper must also output co-occurrence counts for the pairs of
# words inside of each 5-gram. Treat these words as a basket,
# as we have in HW 3, but count all stripes or pairs in both orders,
# i.e., count both orderings: (word1,word2), and (word2,word1), to preserve
# symmetry in our output for TASK (2).
#
# #### Design notes for _TASK (2)_
# For this task you will have to determine a method of comparison.
# Here are a few that you might consider:
#
# - Jaccard
# - Cosine similarity
# - Spearman correlation
# - Euclidean distance
# - Taxicab (Manhattan) distance
# - Shortest path graph distance (a graph, because our data is symmetric!)
# - Pearson correlation
# - Kendall correlation
#
# However, be cautioned that some comparison methods are more difficult to
# parallelize than others, and do not perform more associations than is necessary,
# since your choice of association will be symmetric.
#
# Please use the inverted index (discussed in live session #5) based pattern to compute the pairwise (term-by-term) similarity matrix.
#
# Please report the size of the cluster used and the amount of time it takes to run for the index construction task and for the synonym calculation task. How many pairs need to be processed (HINT: use the posting list length to calculate directly)? Report your  Cluster configuration!

# %% [markdown]
# ## Example MR stats: (report times!)
#     took ~11 minutes on 5 m3.xlarge nodes
#     Data-local map tasks=188
# 	Launched map tasks=190
# 	Launched reduce tasks=15
# 	Other local map tasks=2

# %%
# START STUDENT CODE 5.5
# ADD OR REMOVE CELLS AS NEEDED

# %% [markdown]
# ## NC Outline of Synonym Detection
#
# Please check for (1) logic and (2) how to parallelize / implement with more than one reducer.
#
# This post is a useful reference
# https://ucbischool.slack.com/archives/G5AFVR16J/p1497578722846558
#
# 1. Get a list of the 9,000th to 10,000th most common words in the n-grams. These words will be the words by which we will gauge similarity among all other terms. (See this post).
# https://ucbischool.slack.com/archives/G5AFVR16J/p1497578747849587
#     - This will be tricky to implement with multiple reducers because we need to get a sorted output from multiple partitions. See total sort guide in the 'Resources' folder of the master github repo
# 2. Build slightly modified stripes.
#     - Modified to only include a word in the stripe if it is one of the 9,000th to 10,000th most common words identified in step 1.
#     - In mapper_init phase, read the list of 9,000th to 10,000th most common words into memory.
#     - In the mapper, take each five-gram and loop through all possible pairs of words.
#     - Create a dictionary where the keys are each of the five words in the five-gram and the values are dictionaries that contain the other words in the five-gram and the count that comes with the five-gram.
#         - This is where the modification happens, we want to create a stripe for each word in the five gram, but only include words in the stripe that have been identified as being the 9,000th to 10,000th most common in step 1 above.
# 3. Calculate similarity from stripes created in step 2 above.
#     - Should be able to do this just fine with multiple reducers.
#
#
# #### Stripes Example
#
# Say we have the following ngram (of the form (ngram) \t (count) \t (pages_count) \t (books_count)):
# A Case Study of Female	447	447	327
#
# Say that we have identified that the words 'Study' and 'Female' are in the list of the 9,000th to 10,000th most common words across the google five-gram dataset, but the other words in the five-gram are more common than 9,000th - 10,000th.
#
# We would want our stripes output to look like this:
# a  {study:447, female:447}
# case {study:447, female:447}
# study {female:447}
# of {study:447, female:447}
# female {study:447}
#     - Note, all words in the five-gram have a stripe emitted, but only words that are in the list of 9,000th to 10,000th most common words are actually included in those stripes.

# %% [markdown]
# ### Step 1: Get the 9,001 - 10,000th Words
#
# Need to implement total sort with ordered partitions here. Should be relatively straightforward based on 5.4.1.B above.

# %%
# make sure you have the stopwords corpus

import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Move stopwords corpus to a directory that hadoop will actually check
# stopwords corpus may download to a place that hadoop doesn't look for and you'll get an error when you run mostFrequentWords.py

# !mv /root/nltk_data /home/nltk_data

# %%
# %%writefile mostFrequentWords_rank.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

import re

import mrjob
from mrjob.protocol import RawProtocol
from mrjob.protocol import RawValueProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import nltk
from nltk.corpus import stopwords as sw
from operator import itemgetter
import numpy as np


class mostFrequentWords(MRJob):
    
    #****************************************************
    # Allows values to be treated as keys
    MRJob.SORT_VALUES = True 
    
    # The protocols are critical. It will not work without these:
    INPUT_PROTOCOL = RawValueProtocol
    INTERNAL_PROTOCOL = RawProtocol
    OUTPUT_PROTOCOL = RawProtocol
     
    def __init__(self, *args, **kwargs):
        super(mostFrequentWords, self).__init__(*args, **kwargs)
        self.N = 30
        self.NUM_REDUCERS = 7
    #****************************************************
    #************************************************    
    #Get word counts

        
    def mapper_wc(self, _, line):

        #get the list of tokens in the 5-gram
        token_list = line.strip().lower().split()[:-3]

        #emit each token and a 1   
        for token in token_list:
            if token not in sw.words('english'):
                yield token, str(1)

    def combiner_wc(self, token, count):
        #just do local sums before passing to reducer
        count_sum = 0
        for item in count:
            count_sum += int(item)
        yield token, str(count_sum)            
            
    def reducer_wc(self, token, count):
        count_sum = 0
        for item in count:
            count_sum += int(item)
        yield token, str(count_sum)
        
       
        
    #********************************************************
    #Sort by descending count using total sort with ordered partitions


    #Implement total sort with ordered partitions
    def mapper_partitioner_init(self):
        
        #Function to hash keys
        def makeKeyHash(key, num_reducers):
            byteof = lambda char: int(format(ord(char), 'b'), 2)
            current_hash = 0
            for c in key:
                current_hash = (current_hash * 31 + byteof(c))
            return current_hash % num_reducers
        
        # get the keys: printable ascii characters, starting with 'A'
        keys = [str(unichr(i)) for i in range(65,65+self.NUM_REDUCERS)]
        partitions = []
        
        #Hash each key and link the key to its hashed int value
        for key in keys:
            partitions.append([key, makeKeyHash(key, self.NUM_REDUCERS)])

        #This step re-sorts so that the keys are 'out of order', but the partitions are 'ordered'
        parts = sorted(partitions,key=itemgetter(1))
        self.partition_keys = list(np.array(parts)[:,0])
        
        #NC Note - need to write a separate partition file that mirrors the distribution of your data.
        #Want to end up with roughly equi-sized partitions.
        #The example in the total sort code just assumes a uniform distribution.
        #self.partition_file = np.arange(0,self.N,self.N/(self.NUM_REDUCERS))[::-1]
        #You can mess with the breakpoints here to get evenly sized partitions.
        #Right now, I'm just doing these breakpoints by trial and error to try and get closer to evenly sized partitions.
        #A big improvement would be to make these breakpoints in a more sophisticated way to get evenly sized partitions.
        #Action item 1
        self.partition_file = np.array([34, 12, 6, 3, 2, 1, 0])
        
    #Read line and assign partition key to each line based on the value
    def mapper_partition(self, key, value):

        # Prepend the approriate key by finding the bucket, and using the index to fetch the key.
        #Loop over number of reducers
        for idx in xrange(self.NUM_REDUCERS):
            if float(value) > self.partition_file[idx]:
                #Need to emit the partition key here to leverage the hadoop shuffle phase.
                yield str(self.partition_keys[idx]),key+"\t"+value
                break
       
            
    def reducer_sort(self,key,value):
        for v in value:
            #This emits the partition key for illustration
            #yield key,v
            #This omits the partition key from the output
            yield None, v
    
    #********************************************************
    #Rank by word count
    def mapper_rank_init(self):
        self.rank_counter = 0
        
    def mapper_rank(self, word, count):
        self.rank_counter += 1
        
        if (self.rank_counter > 9000) & (self.rank_counter <= 10000):
            yield word, count
    

    
    
    
    
    
    #********************************************************
    #Steps
    def steps(self):

        
        JOBCONF_STEP1 = {
            'stream.num.map.output.key.fields':3,
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':"\t",
            'mapreduce.partition.keypartitioner.options':'-k1,1',
            'mapreduce.partition.keycomparator.options':'-k3,3nr -k2,2',
            'mapred.reduce.tasks': self.NUM_REDUCERS,
            'partitioner':'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
        }
        
        JOBCONF_STEP3 = {
            'mapred.map.tasks': 1,
        }
        
        return [
            MRStep(mapper=self.mapper_wc,
                   combiner=self.combiner_wc,
                   reducer=self.reducer_wc),
            MRStep(jobconf=JOBCONF_STEP1,
                    mapper_init=self.mapper_partitioner_init,
                    mapper=self.mapper_partition,
                    reducer=self.reducer_sort),
            MRStep(jobconf=JOBCONF_STEP3,
                   mapper_init=self.mapper_rank_init,
                   mapper=self.mapper_rank)
        ]
    
 
    
if __name__ == '__main__':
    mostFrequentWords.run()
# Out:
# Overwriting mostFrequentWords_rank.py

# %%
# !hdfs dfs -rm -r /user/nwchen24/HW5_Phase2

#Hadoop mode for docker container
# !python mostFrequentWords_rank.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt\
    --output-dir='/user/nwchen24/HW5_Phase2'\
    --no-output
# Out:
# rm: `/user/nwchen24/HW5_Phase2': No such file or directory
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/mostFrequentWords_rank.root.20170619.061052.506581
# Copying local files to hdfs:///user/root/tmp/mrjob/mostFrequentWords_rank.root.20170619.061052.506581/files/...
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 3...
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob4768544556773922807.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0107
#   Submitted application application_1497814303217_0107
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0107/
#   Running job: job_1497814303217_0107
#   Job job_1497814303217_0107 running in uber mode : false
#    map 0% reduce 0%
#    map 2% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 83% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497814303217_0107 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/mostFrequentWords_rank.root.20170619.061052.506581/step-output/0000
# Counters: 49
# 	File Input Format Counters
# 		Bytes Read=11448710
# 	File Output Format Counters
# 		Bytes Written=402656
# 	File System Counters
# 		FILE: Number of bytes read=699421
# 		FILE: Number of bytes written=1755997
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=11449132
# 		HDFS: Number of bytes written=402656
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-seconds taken by all map tasks=231229440
# 		Total megabyte-seconds taken by all reduce tasks=3751936
# 		Total time spent by all map tasks (ms)=225810
# 		Total time spent by all maps in occupied slots (ms)=225810
# 		Total time spent by all reduce tasks (ms)=3664
# 		Total time spent by all reduces in occupied slots (ms)=3664
# 		Total vcore-seconds taken by all map tasks=225810
# 		Total vcore-seconds taken by all reduce tasks=3664
# 	Map-Reduce Framework
# 		CPU time spent (ms)=221560
# 		Combine input records=679879
# 		Combine output records=53813
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=95
# 		Input split bytes=422
# 		Map input records=311614
# 		Map output bytes=7046227
# 		Map output materialized bytes=699427
# 		Map output records=679879
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=792735744
# 		Reduce input groups=36206
# 		Reduce input records=53813
# 		Reduce output records=36206
# 		Reduce shuffle bytes=699427
# 		Shuffled Maps =2
# 		Spilled Records=107626
# 		Total committed heap usage (bytes)=730857472
# 		Virtual memory (bytes) snapshot=4091629568
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.reduce.tasks: mapreduce.job.reduces
# Running step 2 of 3...
#   mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob1398518073415554856.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497814303217_0108
#   Submitted application application_1497814303217_0108
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0108/
#   Running job: job_1497814303217_0108
#   Job job_1497814303217_0108 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 14%
#    map 100% reduce 29%
#    map 100% reduce 43%
#    map 100% reduce 57%
#    map 100% reduce 71%
#    map 100% reduce 100%
#   Job job_1497814303217_0108 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/mostFrequentWords_rank.root.20170619.061052.506581/step-output/0001
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=406752
# 	File Output Format Counters
# 		Bytes Written=438862
# 	File System Counters
# 		FILE: Number of bytes read=583728
# 		FILE: Number of bytes written=2241083
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=407118
# 		HDFS: Number of bytes written=438862
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=27
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=2
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Total megabyte-seconds taken by all map tasks=8922112
# 		Total megabyte-seconds taken by all reduce tasks=52283392
# 		Total time spent by all map tasks (ms)=8713
# 		Total time spent by all maps in occupied slots (ms)=8713
# 		Total time spent by all reduce tasks (ms)=51058
# 		Total time spent by all reduces in occupied slots (ms)=51058
# 		Total vcore-seconds taken by all map tasks=8713
# 		Total vcore-seconds taken by all reduce tasks=51058
# 	Map-Reduce Framework
# 		CPU time spent (ms)=12850
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=288
# 		Input split bytes=366
# 		Map input records=36206
# 		Map output bytes=511274
# 		Map output materialized bytes=583770
# 		Map output records=36206
# 		Merged Map outputs=14
# 		Physical memory (bytes) snapshot=1925902336
# 		Reduce input groups=36206
# 		Reduce input records=36206
# 		Reduce output records=36206
# 		Reduce shuffle bytes=583770
# 		Shuffled Maps =14
# 		Spilled Records=72412
# 		Total committed heap usage (bytes)=1460666368
# 		Virtual memory (bytes) snapshot=12258471936
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.map.tasks: mapreduce.job.maps
# mapred.output.key.comparator.class: mapreduce.job.output.key.comparator.class
# mapred.text.key.comparator.options: mapreduce.partition.keycomparator.options
# mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 3 of 3...
#   mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob1609777214155165569.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 7
#   number of splits:7
#   Submitting tokens for job: job_1497814303217_0109
#   Submitted application application_1497814303217_0109
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497814303217_0109/
#   Running job: job_1497814303217_0109
#   Job job_1497814303217_0109 running in uber mode : false
#    map 0% reduce 0%
#    map 14% reduce 0%
#    map 29% reduce 0%
#    map 43% reduce 0%
#    map 57% reduce 0%
#    map 71% reduce 0%
#    map 86% reduce 0%
#    map 100% reduce 0%
#   Job job_1497814303217_0109 completed successfully
#   Output directory: hdfs:///user/nwchen24/HW5_Phase2
# Counters: 30
# 	File Input Format Counters
# 		Bytes Read=438862
# 	File Output Format Counters
# 		Bytes Written=12202
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=826749
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=440143
# 		HDFS: Number of bytes written=12202
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=35
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=7
# 		Launched map tasks=7
# 		Total megabyte-seconds taken by all map tasks=42033152
# 		Total time spent by all map tasks (ms)=41048
# 		Total time spent by all maps in occupied slots (ms)=41048
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total vcore-seconds taken by all map tasks=41048
# 	Map-Reduce Framework
# 		CPU time spent (ms)=4100
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=264
# 		Input split bytes=1281
# 		Map input records=36206
# 		Map output records=1000
# 		Merged Map outputs=0
# 		Physical memory (bytes) snapshot=1165283328
# 		Spilled Records=0
# 		Total committed heap usage (bytes)=1007157248
# 		Virtual memory (bytes) snapshot=9568186368
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/mostFrequentWords_rank.root.20170619.061052.506581...
# Removing temp directory /tmp/mostFrequentWords_rank.root.20170619.061052.506581...

# %%
# !hdfs dfs -ls /user/nwchen24/HW5_Phase2

# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | wc -l
print "="*100
# Out:
# Found 8 items
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/_SUCCESS
# -rw-r--r--   1 root supergroup      12202 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00000
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00001
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00002
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00003
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00004
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00005
# -rw-r--r--   1 root supergroup          0 2017-06-19 06:14 /user/nwchen24/HW5_Phase2/part-00006
# nonuniform	1
# nonunion	1
# nonuse	1
# nonverbal	1
# nonviolent	1
# 1000
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================

# %%
#Action item 2
#Pull the list of 9,000th - 10,000th most common words out of HDFS to be read into memory by the mappers in Step 2 below.

# %%
# !wc words_9k_10k_stop_words
# Out:
#  1000  2000 12876 words_9k_10k_stop_words

# %% [markdown]
# ### Step 2: Build Stripes
#
# Build stripes for all words in n-grams, but the only entries in the stripes are the 9k - 10k words

# %%
# %%writefile buildStripes.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import re
import mrjob
import json
from mrjob.protocol import RawProtocol
from mrjob.job import MRJob
from mrjob.step import MRStep
import itertools
import collections as cl
import ast

class MRbuildStripes(MRJob):
  
    #START SUDENT CODE531_STRIPES
    
    #OUTPUT_PROTOCOL = JSONValueProtocol
    
    def steps(self):
        
        JOBCONF_STEP = {
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':'\t',    
            'mapreduce.partition.keycomparator.options': '-k1,1',
            'mapreduce.job.reduces': '1'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP,
                   mapper_init=self.mapper_init,
                   mapper=self.mapper,
                   reducer=self.reducer
                  )
        ]
    
    def mapper_init(self):
        self.increment_counter('group', 'Num_mapperInit_calls', 1)

# slightly different way you could read in the 9k-10k word list
#         self.words_list = []
        
#         with open("words_9k_10k") as file:
#             for line in file:
#                 self.words_list.append(line.split()[0].strip("\""))
                
        
        self.words_9k_10k = open("words_9k_10k").readlines()
        self.words_9k_10k_list = []

        for line in self.words_9k_10k:
            #Add each word to the list
            self.words_9k_10k_list.append(line.split()[0].strip("\""))
 
        #yield self.words_9k_10k_list,None
    def mapper(self, _, line):
        
        #instantiate dict to hold stripes
        stripes_dict = {}
        
        #parse the co-occurrence count from the line
        co_occur_count = line.strip().split()[-3]

        #get pairs of words in the 5-gram and create a stripe for each unique word
        #Note the set here ensures that a word that appears more than once in a 5-gram won't be counted as co-occurring with itself
        #Note the permutations here will count both (word1,word2) and (word2,word1)
        for subset in itertools.permutations(sorted(set(line.strip().lower().split()[:-3])), 2):
            if subset[1].strip("\"") not in self.words_9k_10k_list:
                pass #could also use "continue"... not much difference in this particular scenario though
            
            else:
                if subset[0].strip("\"") not in stripes_dict.keys():
                    stripes_dict[subset[0].strip("\"")] = {}
                    stripes_dict[subset[0].strip("\"")][subset[1].strip("\"")] = int(co_occur_count)

                elif subset[1].strip("\"") not in stripes_dict[subset[0].strip("\"")]:
                    stripes_dict[subset[0].strip("\"")][subset[1].strip("\"")] = int(co_occur_count)

                else:
                    stripes_dict[subset[0].strip("\"")][subset[1].strip("\"")] += int(co_occur_count)
        
        for key in stripes_dict:
            yield key, stripes_dict[key]
            #yield key, json.dumps(stripes_dict[key])
     
    def reducer(self,key,stripe):
        
        #instantiate counter to hold combined stripes
        cur_counter = cl.Counter()
                
        for stripe_dict in stripe:
            cur_key = key
            
            #load the stripe into a dict
            stripe_dict_to_add = stripe_dict
            
            #update with each stripe
            cur_counter.update(stripe_dict_to_add)

        #output the key and the counter with the sum of all co-occurrences for that key
        yield key, cur_counter

    #END SUDENT CODE531_STRIPES

if __name__ == '__main__':
    MRbuildStripes.run()
# Out:
# Overwriting buildStripes.py

# %%
#Local works
#!python buildStripes.py -r local --file=words_9k_10k googlebooks-eng-all-5gram-20090715-0-filtered.txt > build_stripes_test   

#Hadoop mode for docker container
#As a temporary testing measure, send the stripes results to a single file.
#!python buildStripes.py -r hadoop --file=words_9k_10k_stop_words googlebooks-eng-all-5gram-20090715-0-filtered.txt > build_stripes_test   

#Hadoop  mode for docker container that outputs to HDFS
# !python buildStripes.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered.txt\
    --output-dir='/user/nwchen24/HW5_Phase2'\
    --no-output  
    
#Hadoop to try in altiscale
#!python buildStripes.py -r hadoop --file=words_9k_10k googlebooks-eng-all-5gram-20090715-0-filtered.txt > build_stripes_test \
#    --python-bin=./my_env27_for_hadoop_upload/bin/python \
#    --archive=hdfs:///user/nwchen24/virtualenv/my_env27_for_hadoop_upload.zip#my_env27_for_hadoop_upload
# Out:
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/buildStripes.root.20170619.142324.231831
# Copying local files to hdfs:///user/root/tmp/mrjob/buildStripes.root.20170619.142324.231831/files/...
# Running step 1 of 1...
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob579439806431077025.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   PriviledgedActionException as:root (auth:SIMPLE) cause:org.apache.hadoop.mapred.FileAlreadyExistsException: Output directory hdfs://quickstart.cloudera:8020/user/nwchen24/HW5_Phase2 already exists
#   PriviledgedActionException as:root (auth:SIMPLE) cause:org.apache.hadoop.mapred.FileAlreadyExistsException: Output directory hdfs://quickstart.cloudera:8020/user/nwchen24/HW5_Phase2 already exists
#   Error Launching job : Output directory hdfs://quickstart.cloudera:8020/user/nwchen24/HW5_Phase2 already exists
#   Streaming Command Failed!
# Attempting to fetch counters from logs...
# Can't fetch history log; missing job ID
# No counters found
# Scanning logs for probable cause of failure...
# Can't fetch history log; missing job ID
# Can't fetch task logs; missing application ID
# Step 1 of 1 failed: Command '['/usr/bin/hadoop', 'jar', '/usr/lib/hadoop-mapreduce/hadoop-streaming.jar', '-files', 'hdfs:///user/root/tmp/mrjob/buildStripes.root.20170619.142324.231831/files/buildStripes.py#buildStripes.py,hdfs:///user/root/tmp/mrjob/buildStripes.root.20170619.142324.231831/files/mrjob.zip#mrjob.zip,hdfs:///user/root/tmp/mrjob/buildStripes.root.20170619.142324.231831/files/setup-wrapper.sh#setup-wrapper.sh', '-D', u'mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator', '-D', u'mapreduce.job.reduces=1', '-D', u'mapreduce.partition.keycomparator.options=-k1,1', '-D', u'stream.map.output.field.separator=\t', '-input', 'hdfs:///user/root/tmp/mrjob/buildStripes.root.20170619.142324.231831/files/googlebooks-eng-all-5gram-20090715-0-filtered.txt', '-output', 'hdfs:///user/nwchen24/HW5_Phase2', '-mapper', 'sh -ex setup-wrapper.sh /opt/anaconda/bin/python buildStripes.py --step-num=0 --mapper', '-reducer', 'sh -ex setup-wrapper.sh /opt/anaconda/bin/python buildStripes.py --step-num=0 --reducer']' returned non-zero exit status 1280

# %%
# !wc -l build_stripes_test
# !head -5 build_stripes_test
# Out:
# 5528 build_stripes_test
# "a"	{"semantic":209,"heriot":47,"vile":41,"crosshairs":349,"livelihood":2523,"crocodile":65,"recess":74,"forged":380,"understandable":50,"allowances":227,"quartered":108,"undisputed":83,"shattered":44,"wanton":40,"baron":73,"suits":59,"dissatisfied":42,"determinations":318,"haughtiness":73,"straightforward":138,"infringement":70,"apoptosis":180,"hatter":449,"denman":44,"replication":138,"decedent's":130,"minded":56,"posture":243,"timely":195,"gipsy":45,"denounced":44,"norfolk":390,"abhorrence":43,"dictatorship":68,"couched":283,"guiding":124,"lever":306,"quicker":165,"frenna's":43,"pragmatic":267,"colossal":246,"waking":218,"feasibility":166,"elegant":44,"drafted":179,"boldness":49,"casual":260,"dissertation":83,"relieving":239,"wreck":60,"inferences":138,"designing":241,"retention":128,"amounting":59,"inducement":88,"decanters":43,"proclaiming":42,"predicting":463,"ferocious":52,"stance":397,"reporter":219,"hairs":197,"herd":332,"inconsiderable":2084,"cylindrical":275,"compressed":89,"interposed":140,"luggage":59,"enmity":115,"creepy":55,"mentions":46,"fourier":262,"curable":129,"hectic":86,"regeneration":74,"diametrically":72,"italians":60,"rican":45,"isles":55,"corrupted":105,"dangle":49,"assuring":331,"rainfall":65,"approving":101,"abnormalities":611,"antigens":141,"hailstorm":41,"arranging":554,"tearing":53,"pretense":167,"sculptor":71,"balls":48,"debater":44,"arched":188,"meek":220,"tokyo":58,"cremona":87,"labeled":63,"drill":51,"cab":351,"emphatically":40,"appraisal":54,"il":48,"gymkhanas":48,"spy":360,"embarrassing":63,"triple":403,"calories":179,"galleries":49,"drawer":740,"degenerate":108,"scar":210,"fillip":50,"awkward":124,"sate":52,"gaping":516,"ancestor":58,"memoir":402,"dignified":120,"banker":479,"watery":347,"inputs":606,"designer":307,"ft":73,"dei":61,"halted":870,"pigs":257,"floated":77,"fray":74,"ambiguous":113,"dissolving":45,"biographical":365,"arduous":108,"darkened":79,"negligible":159,"contributes":206,"healthfulness":40,"intellectuals":172,"cruelties":42,"crumple":72,"determinate":154,"remnants":243,"deliberative":56,"oven":326,"bridges":84,"haughty":119,"taxpayer":52,"curacy":48,"abbey":446,"lt":136,"croquet":42,"haamau":40,"fin":112,"colleague":48,"orifice":190,"crash":1149,"halt":127,"richness":50,"educating":79,"crucifying":42,"dissatisfaction":187,"inversion":110,"thrill":395,"backgrounds":198,"capability":98,"peking":49,"aggrieved":45,"cliffs":47,"interfering":48,"glasses":281,"barrels":129,"illuminate":142,"upstairs":90,"another's":92,"needless":46,"dreaming":86,"manifests":204,"burdened":311,"furtherance":53,"hanged":42,"ambassadors":49,"heave":60,"sunrise":51,"gallant":64,"crowing":45,"disbelieves":66,"sociological":62,"mate":116,"arkansas":43,"wondrous":177,"shipment":63,"induction":57,"troop":467,"benjamin":118,"hailing":54,"proviso":108,"forcible":449,"democratical":61,"hull":48,"cyclopean":48,"brooks":166,"mourning":128,"campaigns":65,"conditioning":52,"aragonese":44,"cough":273,"diffused":90,"laborer":420,"derivation":367,"waiter":159,"cosmic":42,"birthday":116,"soda":86,"baltic":65,"blush":62,"throws":323,"arterial":94,"crib":40,"peculiarity":322,"fantasy":176,"floors":118,"finder's":52,"habitation":57,"insulation":124,"disinterested":95,"fuller":581,"acquaint":81,"financed":133,"faradic":84,"shilling":231,"confirming":278,"decentralised":72,"inconvenient":117,"finances":117,"boil":949,"reparation":46,"fiery":107,"dresses":145,"favorably":58,"thoracic":80,"circulated":68,"broadcast":889,"dentist":172,"daddy's":82,"hazelnut":361,"corresponded":124,"consonant":102,"brushed":408,"haven":122,"here's":42,"collectively":45,"tavern":353,"calamity":119,"architect":74,"spoiled":156,"gigantic":226,"damned":53,"bet":275,"imaginative":286,"addressing":89,"curtains":48,"cytoplasm":106,"fights":94,"deflationary":46,"generalization":900,"decapitated":97,"uninterrupted":373,"curved":255,"borough":51,"seminar":193,"ratings":87,"hammer":106,"veteran":254,"couch":40,"fanfoa":44,"sect":241,"insulated":110, ...
# "aa"	{"jackson":43}
# "abdominal"	{"thoracic":80}
# "abduction"	{"forcible":363}
# "abelard"	{"heloise":277}

# %% [markdown]
# ### Step 3: Calculate Similarities

# %%
# %%writefile similarity.py
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

from __future__ import division
import re
import mrjob
from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol
from mrjob.protocol import RawProtocol
from operator import itemgetter
import numpy as np
import itertools
import json
import math
import collections
import ast


class MRsimilarity(MRJob):
  
    #START SUDENT CODE531_SIMILARITY
    #OUTPUT_PROTOCOL = JSONValueProtocol

                
    #****************************************************
    # Allows values to be treated as keys
    MRJob.SORT_VALUES = True 
    
    # The protocols are critical. Total sort will not work without these:
    #Raw protocols require emitting strings from each phase
    INPUT_PROTOCOL = RawValueProtocol
    INTERNAL_PROTOCOL = RawProtocol
    OUTPUT_PROTOCOL = RawProtocol
     
    def __init__(self, *args, **kwargs):
        super(MRsimilarity, self).__init__(*args, **kwargs)
        self.N = 30
        self.NUM_REDUCERS = 7
    #****************************************************


    def mapper(self, _, line):
        
        #Read the key and the stripe from the input
        key_index_list = line.translate(None,"\n").split("\t")
        
        key = json.loads(key_index_list[0])
        inv_index = json.loads(key_index_list[1])
        
        for subset in itertools.permutations(sorted(set(inv_index.keys())), 2):
            
            #get the lengths of each item that we want to output
            item_1_len = inv_index[subset[0]]
            item_2_len = inv_index[subset[1]]
            
            #create a two item dict to hold the item names and their lengths
            item_len_dict = {}
            item_len_dict[subset[0]] = item_1_len
            item_len_dict[subset[1]] = item_2_len
            
            #when output like this, can index with key[0] to get subset[0] in the reducer
            #yield (subset[0], subset[1]), (1,item_len_dict)
            yield subset[0]+"|"+subset[1], str(1)+"\t"+str(item_len_dict)
            
    def reducer_test(self, key, stripe):
        for mapper_out in stripe:
            
            #interpret the dict output from the mapper as a string
            #item_len_dict = ast.literal_eval(mapper_out[1])
            #get the counter output from the mapper
            #n = int(mapper_out[0])
            
            mapper_out_list = mapper_out.split("\t")
            
            yield key, mapper_out_list[0]+" AND "+mapper_out_list[1]
    
    
    def reducer(self, key, stripe):

        #instantiate object to hold the number of times the terms / documents intersect
        items_intersect = 0
        cosine_sim_product = 0
        
        #Split the compound key to get each word individually
        key_list = key.split("|")
        
        #the reducer gets output from the mapper in chunks grouped by key
        #for n,item_len_dict in stripe:
        for mapper_out in stripe:
            
            #Parse the mapper_out which is a string of count and the length dict separated by a tab
            mapper_out_list = mapper_out.split("\t")
            
            #interpret the dict output from the mapper as a string
            item_len_dict = ast.literal_eval(mapper_out_list[1])
            #get the counter output from the mapper
            n = int(mapper_out_list[0])
            
            #get the length of item 1 and item 2
            item_1_len = item_len_dict[key_list[0]]
            item_2_len = item_len_dict[key_list[1]]
            
            #increment the intersect count
            items_intersect = items_intersect + n
            
            cosine_sim_product = cosine_sim_product + (1/np.sqrt(item_1_len)) * (1/np.sqrt(item_2_len))
            
        #calculate jacard similarity score
        jacard_sim_score = float(items_intersect)/ float(item_1_len + item_2_len - items_intersect)
        
        #Record cosine similarity score before moving on to the next chunk
        cosine_sim_score = cosine_sim_product
        
        #average sim score
        avg_sim_score = (jacard_sim_score + cosine_sim_score) / 2
        
        yield key, str(avg_sim_score)+"\t"+str(jacard_sim_score)+"\t"+str(cosine_sim_score)   

        
    
    #*********************************************************************
    #Sort the partitions in descending order of average sim score
    #Implement total sort with ordered partitions
    def mapper_partitioner_init(self):
        
        #Function to hash keys
        def makeKeyHash(key, num_reducers):
            byteof = lambda char: int(format(ord(char), 'b'), 2)
            current_hash = 0
            for c in key:
                current_hash = (current_hash * 31 + byteof(c))
            return current_hash % num_reducers
        
        # get the keys: printable ascii characters, starting with 'A'
        keys = [str(unichr(i)) for i in range(65,65+self.NUM_REDUCERS)]
        partitions = []
        
        #Hash each key and link the key to its hashed int value
        for key in keys:
            partitions.append([key, makeKeyHash(key, self.NUM_REDUCERS)])

        #This step re-sorts so that the keys are 'out of order', but the partitions are 'ordered'
        parts = sorted(partitions,key=itemgetter(1))
        self.partition_keys = list(np.array(parts)[:,0])
        
        #NC Note - need to write a separate partition file that mirrors the distribution of your data.
        #Want to end up with roughly equi-sized partitions.
        #The example in the total sort code just assumes a uniform distribution.
        #self.partition_file = np.arange(0,self.N,self.N/(self.NUM_REDUCERS))[::-1]
        #You can mess with the breakpoints here to get evenly sized partitions.
        #Right now, I'm just doing these breakpoints by trial and error to try and get closer to evenly sized partitions.
        #A big improvement would be to make these breakpoints in a more sophisticated way to get evenly sized partitions.
        #Action item 1
        #Will need to adjust these partitions based on the similarity scores we observe in the full google 5-grams
        #If we want 7 reducers, this list should have 7 breakpoints. With 8 reducers, we would want 8 breakpoints. etc.
        self.partition_file = np.array([.9, .6, .4, 0.3, 0.2, 0.1, 0])
        
    
    #Read line and assign partition key to each line based on the value
    def mapper_partition(self, key, value):

        value_list = value.split("\t")
        avg_sim_score = value_list[0]
        # Prepend the approriate key by finding the bucket, and using the index to fetch the key.
        #Loop over number of reducers
        for idx in xrange(self.NUM_REDUCERS):
            if float(avg_sim_score) > self.partition_file[idx]:
                #Need to emit the partition key here to leverage the hadoop shuffle phase.
                yield str(self.partition_keys[idx]),key+"\t"+value
                break
       
            
    def reducer_sort(self,key,value):
        for v in value:
            #This emits the partition key for illustration
            #yield key,v
            #This omits the partition key from the output
            yield None, v
    
    
    def steps(self):


        JOBCONF_STEP = {
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':'\t',    
            'stream.num.map.output.key.fields': '2',
            'mapreduce.partition.keycomparator.options': '-k1,1',
            'mapreduce.job.reduces': self.NUM_REDUCERS
        }
        
        JOBCONF_STEP2 = {
            'stream.num.map.output.key.fields':4,
            'mapreduce.job.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'stream.map.output.field.separator':"\t",
            'mapreduce.partition.keypartitioner.options':'-k1,1',
            'mapreduce.partition.keycomparator.options':'-k3,3nr -k2,2',
            'mapred.reduce.tasks': self.NUM_REDUCERS,
            'partitioner':'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
        }
        
        return [
            MRStep(jobconf=JOBCONF_STEP,
                   mapper=self.mapper,
                   reducer=self.reducer),
            MRStep(jobconf=JOBCONF_STEP2,
                    mapper_init=self.mapper_partitioner_init,
                    mapper=self.mapper_partition,
                    reducer=self.reducer_sort
                  )
        ]
                  
        
        
    #END SUDENT CODE531_SIMILARITY

if __name__ == '__main__':
    MRsimilarity.run()
# Out:
# Overwriting similarity.py

# %% [markdown]
# Action item 3 - need to get this code below to be able to read in the partitions of stripes that are output from the step above. The stripes partitions will be output to the hdfs directory /user/nwchener/HW5_Phase2.
#
# As a temporary testing measure for the similarity code, I saved stripes to the file build_stripes_test which is fed to the similarity code below.

# %%
# !hdfs dfs -rm -r /user/nwchen24/HW5_Phase2

#Hadoop mode with only first ten lines
#!python similarity.py -r hadoop googlebooks-eng-all-5gram-20090715-0-filtered-first-10-lines.txt > total_sort_density_test

#Hadoop mode for docker container
# !python similarity.py -r hadoop build_stripes_test\
    --output-dir='/user/nwchen24/HW5_Phase2'\
    --no-output
# Out:
# Deleted /user/nwchen24/HW5_Phase2
# Using configs in /etc/mrjob.conf
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /home/hadoop/contrib...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/similarity.root.20170619.135650.082349
# Copying local files to hdfs:///user/root/tmp/mrjob/similarity.root.20170619.135650.082349/files/...
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.text.key.partitioner.options: mapreduce.partition.keypartitioner.options
# Running step 1 of 2...
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob9169585631210292291.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497874416677_0012
#   Submitted application application_1497874416677_0012
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497874416677_0012/
#   Running job: job_1497874416677_0012
#   Job job_1497874416677_0012 running in uber mode : false
#    map 0% reduce 0%
#    map 33% reduce 0%
#    map 67% reduce 0%
#    map 83% reduce 0%
#    map 83% reduce 2%
#    map 83% reduce 5%
#    map 83% reduce 7%
#    map 83% reduce 12%
#    map 90% reduce 12%
#    map 100% reduce 12%
#    map 100% reduce 16%
#    map 100% reduce 23%
#    map 100% reduce 45%
#    map 100% reduce 48%
#    map 100% reduce 49%
#    map 100% reduce 50%
#    map 100% reduce 51%
#    map 100% reduce 52%
#    map 100% reduce 53%
#    map 100% reduce 54%
#    map 100% reduce 65%
#    map 100% reduce 66%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497874416677_0012 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/similarity.root.20170619.135650.082349/step-output/0000
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=361782
# 	File Output Format Counters
# 		Bytes Written=103256402
# 	File System Counters
# 		FILE: Number of bytes read=450701073
# 		FILE: Number of bytes written=710396767
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=362116
# 		HDFS: Number of bytes written=103256402
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=27
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=2
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Total megabyte-seconds taken by all map tasks=57405440
# 		Total megabyte-seconds taken by all reduce tasks=383222784
# 		Total time spent by all map tasks (ms)=56060
# 		Total time spent by all maps in occupied slots (ms)=56060
# 		Total time spent by all reduce tasks (ms)=374241
# 		Total time spent by all reduces in occupied slots (ms)=374241
# 		Total vcore-seconds taken by all map tasks=56060
# 		Total vcore-seconds taken by all reduce tasks=374241
# 	Map-Reduce Framework
# 		CPU time spent (ms)=222220
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=1615
# 		Input split bytes=334
# 		Map input records=5014
# 		Map output bytes=249625416
# 		Map output materialized bytes=258671652
# 		Map output records=4523076
# 		Merged Map outputs=14
# 		Physical memory (bytes) snapshot=2770280448
# 		Reduce input groups=1565392
# 		Reduce input records=4523076
# 		Reduce output records=1565392
# 		Reduce shuffle bytes=258671652
# 		Shuffled Maps =14
# 		Spilled Records=12392806
# 		Total committed heap usage (bytes)=2335178752
# 		Virtual memory (bytes) snapshot=12311195648
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.6.0:
# The have been translated as follows
#  mapred.reduce.tasks: mapreduce.job.reduces
# Running step 2 of 2...
#   mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
#   mapred.text.key.partitioner.options is deprecated. Instead, use mapreduce.partition.keypartitioner.options
#   packageJobJar: [] [/usr/jars/hadoop-streaming-2.6.0-cdh5.7.0.jar] /tmp/streamjob3809937368569604168.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Total input paths to process : 7
#   number of splits:7
#   Submitting tokens for job: job_1497874416677_0013
#   Submitted application application_1497874416677_0013
#   The url to track the job: http://quickstart.cloudera:8088/proxy/application_1497874416677_0013/
#   Running job: job_1497874416677_0013
#   Job job_1497874416677_0013 running in uber mode : false
#    map 0% reduce 0%
#    map 10% reduce 0%
#    map 19% reduce 0%
#    map 24% reduce 0%
#    map 33% reduce 0%
#    map 38% reduce 0%
#    map 52% reduce 0%
#    map 62% reduce 0%
#    map 67% reduce 0%
#    map 81% reduce 0%
#    map 86% reduce 0%
#    map 100% reduce 43%
#    map 100% reduce 71%
#    map 100% reduce 86%
#    map 100% reduce 96%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497874416677_0013 completed successfully
#   Output directory: hdfs:///user/nwchen24/HW5_Phase2
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=103256402
# 	File Output Format Counters
# 		Bytes Written=103256402
# 	File System Counters
# 		FILE: Number of bytes read=109518012
# 		FILE: Number of bytes written=220703781
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=103257592
# 		HDFS: Number of bytes written=103256402
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=42
# 		HDFS: Number of write operations=14
# 	Job Counters
# 		Data-local map tasks=7
# 		Killed reduce tasks=1
# 		Launched map tasks=7
# 		Launched reduce tasks=8
# 		Total megabyte-seconds taken by all map tasks=91698176
# 		Total megabyte-seconds taken by all reduce tasks=63541248
# 		Total time spent by all map tasks (ms)=89549
# 		Total time spent by all maps in occupied slots (ms)=89549
# 		Total time spent by all reduce tasks (ms)=62052
# 		Total time spent by all reduces in occupied slots (ms)=62052
# 		Total vcore-seconds taken by all map tasks=89549
# 		Total vcore-seconds taken by all reduce tasks=62052
# 	Map-Reduce Framework
# 		CPU time spent (ms)=48920
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=923
# 		Input split bytes=1190
# 		Map input records=1565392
# 		Map output bytes=106387186
# 		Map output materialized bytes=109518264
# 		Map output records=1565392
# 		Merged Map outputs=49
# 		Physical memory (bytes) snapshot=4268146688
# 		Reduce input groups=1565392
# 		Reduce input records=1565392
# 		Reduce output records=1565392
# 		Reduce shuffle bytes=109518264
# 		Shuffled Maps =49
# 		Spilled Records=3130784
# 		Total committed heap usage (bytes)=3656384512
# 		Virtual memory (bytes) snapshot=19095023616
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/similarity.root.20170619.135650.082349...
# Removing temp directory /tmp/similarity.root.20170619.135650.082349...

# %% [markdown]
# ## NC Note:
# I am getting very low similarity scores when running on a single one of the google 5-gram files. I am hoping this is because it is just a small subset and not some error in the calculation.

# %%
# !hdfs dfs -ls /user/nwchen24/HW5_Phase2

# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00000 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00001 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00002 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00003 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00004 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00005 | wc -l
print "="*100
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | head -n 5
# !hdfs dfs -cat /user/nwchen24/HW5_Phase2/part-00006 | wc -l
print "="*100
# Out:
# Found 8 items
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/_SUCCESS
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00000
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00001
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00002
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00003
# -rw-r--r--   1 root supergroup          0 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00004
# -rw-r--r--   1 root supergroup      41280 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00005
# -rw-r--r--   1 root supergroup  103215122 2017-06-19 13:59 /user/nwchen24/HW5_Phase2/part-00006
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# 0
# ====================================================================================================
# graceful|exemplified	0.179583073339	0.181818181818	0.17734796486
# startled|appearances	0.169184952608	0.2	0.138369905216
# sensibility|malice	0.161531500655	0.155844155844	0.167218845466
# graceful|pathetic	0.160388623361	0.155844155844	0.164933090877
# aided|graceful	0.159642174358	0.150537634409	0.168746714307
# cat: Unable to write to output stream.
# 664
# ====================================================================================================
# revived|insensible	0.0999377518374	0.109756097561	0.0901194061138
# graceful|innovations	0.0999252925265	0.0791366906475	0.120713894406
# appearances|abiding	0.0999167716095	0.106666666667	0.0931668765524
# purified|substituting	0.0999111170661	0.104761904762	0.0950603293703
# pathetic|ornament	0.0998307513628	0.0814814814815	0.118180021244
# cat: Unable to write to output stream.
# 1564728
# ====================================================================================================

# %%
# END STUDENT CODE 5.5

# %%
print "\nTop/Bottom 20 results - Similarity measures - sorted by cosine"
print "(From the entire data set)"
print '—'*117
print "{0:>30} |{1:>15} |{2:>15} |{3:>15} |{4:>15} |{5:>15}".format(
        "pair", "cosine", "jaccard", "overlap", "dice", "average")
print '-'*117

for stripe in sortedSims[:20]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

print '—'*117

for stripe in sortedSims[-20:]:
    print "{0:>30} |{1:>15f} |{2:>15f} |{3:>15f} |{4:>15f} |{5:>15f}".format(
        stripe[0], float(stripe[1]), float(stripe[2]), float(stripe[3]), float(stripe[4]), float(stripe[5]) )

# %%
Top/Bottom 20 results - Similarity measures - sorted by cosine
(From the entire data set)
—————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
                          pair |         cosine |        jaccard |        overlap |           dice |        average
---------------------------------------------------------------------------------------------------------------------
                   cons - pros |       0.894427 |       0.800000 |       1.000000 |       0.888889 |       0.895829
            forties - twenties |       0.816497 |       0.666667 |       1.000000 |       0.800000 |       0.820791
                    own - time |       0.809510 |       0.670563 |       0.921168 |       0.802799 |       0.801010
                 little - time |       0.784197 |       0.630621 |       0.926101 |       0.773473 |       0.778598
                  found - time |       0.783434 |       0.636364 |       0.883788 |       0.777778 |       0.770341
                 nova - scotia |       0.774597 |       0.600000 |       1.000000 |       0.750000 |       0.781149
                   hong - kong |       0.769800 |       0.615385 |       0.888889 |       0.761905 |       0.758995
                   life - time |       0.769666 |       0.608789 |       0.925081 |       0.756829 |       0.765091
                  time - world |       0.755476 |       0.585049 |       0.937500 |       0.738209 |       0.754058
                  means - time |       0.752181 |       0.587117 |       0.902597 |       0.739854 |       0.745437
                   form - time |       0.749943 |       0.588418 |       0.876733 |       0.740885 |       0.738995
       infarction - myocardial |       0.748331 |       0.560000 |       1.000000 |       0.717949 |       0.756570
                 people - time |       0.745788 |       0.573577 |       0.923875 |       0.729010 |       0.743063
                 angeles - los |       0.745499 |       0.586207 |       0.850000 |       0.739130 |       0.730209
                  little - own |       0.739343 |       0.585834 |       0.767296 |       0.738834 |       0.707827
                    life - own |       0.737053 |       0.582217 |       0.778502 |       0.735951 |       0.708430
          anterior - posterior |       0.733388 |       0.576471 |       0.790323 |       0.731343 |       0.707881
                  power - time |       0.719611 |       0.533623 |       0.933586 |       0.695898 |       0.720680
              dearly - install |       0.707107 |       0.500000 |       1.000000 |       0.666667 |       0.718443
                   found - own |       0.704802 |       0.544134 |       0.710949 |       0.704776 |       0.666165
—————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
           arrival - essential |       0.008258 |       0.004098 |       0.009615 |       0.008163 |       0.007534
         governments - surface |       0.008251 |       0.003534 |       0.014706 |       0.007042 |       0.008383
                king - lesions |       0.008178 |       0.003106 |       0.017857 |       0.006192 |       0.008833
              clinical - stood |       0.008178 |       0.003831 |       0.011905 |       0.007634 |       0.007887
               till - validity |       0.008172 |       0.003367 |       0.015625 |       0.006711 |       0.008469
            evidence - started |       0.008159 |       0.003802 |       0.012048 |       0.007576 |       0.007896
               forces - record |       0.008152 |       0.003876 |       0.011364 |       0.007722 |       0.007778
               primary - stone |       0.008146 |       0.004065 |       0.009091 |       0.008097 |       0.007350
             beneath - federal |       0.008134 |       0.004082 |       0.008403 |       0.008130 |       0.007187
                factors - rose |       0.008113 |       0.004032 |       0.009346 |       0.008032 |       0.007381
           evening - functions |       0.008069 |       0.004049 |       0.008333 |       0.008065 |       0.007129
                   bone - told |       0.008061 |       0.003704 |       0.012346 |       0.007380 |       0.007873
             building - occurs |       0.008002 |       0.003891 |       0.010309 |       0.007752 |       0.007489
                 company - fig |       0.007913 |       0.003257 |       0.015152 |       0.006494 |       0.008204
               chronic - north |       0.007803 |       0.003268 |       0.014493 |       0.006515 |       0.008020
             evaluation - king |       0.007650 |       0.003030 |       0.015625 |       0.006042 |       0.008087
             resulting - stood |       0.007650 |       0.003663 |       0.010417 |       0.007299 |       0.007257
                 agent - round |       0.007515 |       0.003289 |       0.012821 |       0.006557 |       0.007546
         afterwards - analysis |       0.007387 |       0.003521 |       0.010204 |       0.007018 |       0.007032
            posterior - spirit |       0.007156 |       0.002660 |       0.016129 |       0.005305 |       0.007812

# %% [markdown]
# ## 3.  HW5.6  <a name="5.6"></a> Evaluation of synonyms that your discovered
# [Back to Table of Contents](#TOC)
#
#
# In this part of the assignment you will evaluate the success of you synonym detector (developed in response to HW5.4).
# Take the top 1,000 closest/most similar/correlative pairs of words as determined by your measure in HW5.4, and use the synonyms function in the accompanying python code:
#
# nltk_synonyms.py
#
# Note: This will require installing the python nltk package:
#
# http://www.nltk.org/install.html
#
# and downloading its data with nltk.download().
#
# For each (word1,word2) pair, check to see if word1 is in the list,
# synonyms(word2), and vice-versa. If one of the two is a synonym of the other,
# then consider this pair a 'hit', and then report the precision, recall, and F1 measure  of
# your detector across your 1,000 best guesses. Report the macro averages of these measures.

# %% [markdown]
# ### Calculate performance measures:
# $$Precision (P) = \frac{TP}{TP + FP} $$
# $$Recall (R) = \frac{TP}{TP + FN} $$
# $$F1 = \frac{2 * ( precision * recall )}{precision + recall}$$
#
#
# We calculate Precision by counting the number of hits and dividing by the number of occurances in our top1000 (opportunities)
# We calculate Recall by counting the number of hits, and dividing by the number of synonyms in wordnet (syns)
#
#
# Other diagnostic measures not implemented here:  https://en.wikipedia.org/wiki/F1_score#Diagnostic_Testing

# %%
''' Performance measures '''
from __future__ import division
import numpy as np
import json
import nltk
from nltk.corpus import wordnet as wn
import sys
#print all the synset element of an element
def synonyms(string):
    syndict = {}
    for i,j in enumerate(wn.synsets(string)):
        syns = j.lemma_names()
        for syn in syns:
            syndict.setdefault(syn,1)
    return syndict.keys()
hits = []

TP = 0
FP = 0

TOTAL = 0
flag = False # so we don't double count, but at the same time don't miss hits

top1000sims = []
with open("sims2/top1000sims","r") as f:
    for line in f.readlines():

        line = line.strip()
        avg,lisst = line.split("\t")
        lisst = json.loads(lisst)
        lisst.append(avg)
        top1000sims.append(lisst)
    

measures = {}
not_in_wordnet = []

for line in top1000sims:
    TOTAL += 1

    pair = line[0]
    words = pair.split(" - ")
    
    for word in words:
        if word not in measures:
            measures[word] = {"syns":0,"opps": 0,"hits":0}
        measures[word]["opps"] += 1 
    
    syns0 = synonyms(words[0])
    measures[words[1]]["syns"] = len(syns0)
    if len(syns0) == 0:
        not_in_wordnet.append(words[0])
        
    if words[1] in syns0:
        TP += 1
        hits.append(line)
        flag = True
        measures[words[1]]["hits"] += 1
        
        
        
    syns1 = synonyms(words[1]) 
    measures[words[0]]["syns"] = len(syns1)
    if len(syns1) == 0:
        not_in_wordnet.append(words[1])

    if words[0] in syns1:
        if flag == False:
            TP += 1
            hits.append(line)
            measures[words[0]]["hits"] += 1
            
    flag = False    

precision = []
recall = []
f1 = []

for key in measures:
    p,r,f = 0,0,0
    if measures[key]["hits"] > 0 and measures[key]["syns"] > 0:
        p = measures[key]["hits"]/measures[key]["opps"]
        r = measures[key]["hits"]/measures[key]["syns"]
        f = 2 * (p*r)/(p+r)
    
    # For calculating measures, only take into account words that have synonyms in wordnet
    if measures[key]["syns"] > 0:
        precision.append(p)
        recall.append(r)
        f1.append(f)

    
# Take the mean of each measure    
print "—"*110    
print "Number of Hits:",TP, "out of top",TOTAL
print "Number of words without synonyms:",len(not_in_wordnet)
print "—"*110 
print "Precision\t", np.mean(precision)
print "Recall\t\t", np.mean(recall)
print "F1\t\t", np.mean(f1)
print "—"*110  

print "Words without synonyms:"
print "-"*100

for word in not_in_wordnet:
    print synonyms(word),word

# %% [markdown]
# ### Sample output

# %%
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Number of Hits: 31 out of top 1000
Number of words without synonyms: 67
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Precision	0.0280214404967
Recall		0.0178598869579
F1		0.013965517619
——————————————————————————————————————————————————————————————————————————————————————————————————————————————
Words without synonyms:
----------------------------------------------------------------------------------------------------
[] scotia
[] hong
[] kong
[] angeles
[] los
[] nor
[] themselves
[] 
.......

# %% [markdown]
# ## 3.  HW5.7  <a name="5.7"></a> OPTIONAL: using different vocabulary subsets
# [Back to Table of Contents](#TOC)
#
#
# Repeat HW5 using vocabulary words ranked from 8001,-10,000;  7001,-10,000; 6001,-10,000; 5001,-10,000; 3001,-10,000; and 1001,-10,000;
# Dont forget to report you Cluster configuration.
#
# Generate the following graphs:
# -- vocabulary size (X-Axis) versus CPU time for indexing
# -- vocabulary size (X-Axis) versus number of pairs processed
# -- vocabulary size (X-Axis) versus F1 measure, Precision, Recall

# %% [markdown]
# ## 3.  HW5.8  <a name="5.8"></a> OPTIONAL: filter stopwords
# [Back to Table of Contents](#TOC)
#
# There is also a corpus of stopwords, that is, high-frequency words like "the", "to" and "also" that we sometimes want to filter out of a document before further processing. Stopwords usually have little lexical content, and their presence in a text fails to distinguish it from other texts. Python's nltk comes with a prebuilt list of stopwords (see below). Using this stopword list filter out these tokens from your analysis and rerun the experiments in 5.5 and disucuss the results of using a stopword list and without using a stopword list.
#
# > from nltk.corpus import stopwords
# >> stopwords.words('english')
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
# 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
# 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
# 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
# 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
# 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
# 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
# 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
# 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
# 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
# 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
# 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %% [markdown]
# ## 3.  HW5.9 <a name="5.9"></a> OPTIONAL
# [Back to Table of Contents](#TOC)
#
# There are many good ways to build our synonym detectors, so for this optional homework,
# measure co-occurrence by (left/right/all) consecutive words only,
# or make stripes according to word co-occurrences with the accompanying
# 2-, 3-, or 4-grams (note here that your output will no longer
# be interpretable as a network) inside of the 5-grams.

# %% [markdown]
# ## 3.  HW5.10 <a name="5.10"></a> OPTIONAL
# [Back to Table of Contents](#TOC)
#
# Once again, benchmark your top 10,000 associations (as in 5.5), this time for your
# results from 5.6. Has your detector improved?
